# %% [markdown]
# # Cào dữ liệu bằng API

# %% [markdown]
# Cào bộ dữ liệu laptop chỉ định bằng API trên Web Scraper

# %%
# import requests
# import time

# # Thay thế bằng API Token của bạn
# # API_TOKEN = "9OitUqJaY8N9HN4iAODhQdGTMR8wtWjRe5cVAGAGG0TvnezdTxRQgBi18Zbj"
# BASE_URL = "https://api.webscraper.io/api/v1"

# # 1. Lấy danh sách sitemaps
# def get_sitemaps():
#     url = f"{BASE_URL}/sitemaps?api_token={API_TOKEN}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         sitemaps = response.json().get("data", [])
#         print("Danh sách sitemaps:")
#         for sitemap in sitemaps:
#             print(f"- Tên: {sitemap['name']}, ID: {sitemap['id']}")
#         return sitemaps
#     else:
#         print("Không thể lấy danh sách sitemaps:", response.json())
#         return []

# # 2. Tạo Scraping Job
# def create_scraping_job(sitemap_id):
#     url = f"{BASE_URL}/scraping-job?api_token={API_TOKEN}"
#     payload = {
#         "sitemap_id": sitemap_id,
#         "driver": "fast",  # hoặc "fulljs" tùy theo nhu cầu
#         "page_load_delay": 2000,
#         "request_interval": 2000,
#     }
#     response = requests.post(url, json=payload)
#     if response.status_code == 200 and response.json().get("success"):
#         job_id = response.json()["data"]["id"]
#         print(f"Scraping job được tạo thành công. Job ID: {job_id}")
#         return job_id
#     else:
#         print("Không thể tạo scraping job:", response.json())
#         return None

# # 3. Kiểm tra trạng thái Job
# def check_job_status(job_id):
#     url = f"{BASE_URL}/scraping-job/{job_id}?api_token={API_TOKEN}"
#     while True:
#         response = requests.get(url)
#         if response.status_code == 200:
#             status = response.json()["data"]["status"]
#             print(f"Trạng thái job: {status}")
#             if status == "finished":
#                 print("Scraping job đã hoàn thành.")
#                 break
#             elif status in ["failed", "stopped"]:
#                 print("Scraping job thất bại hoặc bị dừng.")
#                 return False
#         else:
#             print("Không thể kiểm tra trạng thái job:", response.json())
#             return False
#         time.sleep(10)  # Đợi 10 giây trước khi kiểm tra lại
#     return True

# # 4. Tải dữ liệu đã cào
# def download_data(job_id, file_name, file_format="json"):
#     url = f"{BASE_URL}/scraping-job/{job_id}/{file_format}?api_token={API_TOKEN}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         with open(file_name, "wb") as f:
#             f.write(response.content)
#         print(f"Dữ liệu đã được tải thành công vào file {file_name}.")
#     else:
#         print("Không thể tải dữ liệu:", response.json())

# # 5. Chạy toàn bộ quy trình
# def scrape_sitemap():
#     while True:
#         sitemaps = get_sitemaps()
#         if not sitemaps:
#             break
        
#         # Nhập ID sitemap muốn cào
#         sitemap_id = input("Nhập ID của sitemap muốn cào: ").strip()
        
#         # Kiểm tra sitemap_id có hợp lệ không
#         selected_sitemap = next((s for s in sitemaps if str(s["id"]) == sitemap_id), None)
#         if not selected_sitemap:
#             print(f"Bạn đã nhập Sitemap ID: {sitemap_id}")
#             print(f"Sitemap ID hợp lệ: {[str(s['id']) for s in sitemaps]}")
#             print("Sitemap ID không hợp lệ. Vui lòng thử lại.")
#             continue

        
#         # Lấy tên sitemap để đặt tên file
#         sitemap_name = selected_sitemap["name"]
#         file_name = f"{sitemap_name}.csv"  # Đặt file theo tên sitemap
        
#         # Tạo job và cào dữ liệu
#         job_id = create_scraping_job(sitemap_id)
#         if job_id and check_job_status(job_id):
#             download_data(job_id, file_name)
        
#         # Hỏi người dùng có muốn tiếp tục không
#         continue_scraping = input("Bạn có muốn tiếp tục cào (y/n)? (mất phí :(( mỗi lần cào)").strip().lower()
#         if continue_scraping != "y":
#             print("Kết thúc chương trình.")
#             break

# if __name__ == "__main__":
#     scrape_sitemap()

# %% [markdown]
# # Tiền Xử Lý dữ liệu

# %% [markdown]
# ## Tiền xử lý LaptopAZ và Laptops_anphat

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder

# 1. Đọc dữ liệu từ file Excel
df_LaptopAZ = pd.read_excel('LaptopAZ.xlsx')
df_LaptopAZ['Link']=df_LaptopAZ['Link san pham-href']
# 2. Xóa các cột không liên quan
columns_to_drop = [
    'web-scraper-order', 'web-scraper-start-url', 'Link trang', 
    'Link trang-href', 'Link san pham', 'Link san pham-href', 'OS_'
]
df_LaptopAZ = df_LaptopAZ.drop(columns=columns_to_drop)

# 3. Xử lý các giá trị thiếu
# Loại bỏ các hàng có giá trị thiếu
df_LaptopAZ = df_LaptopAZ.dropna(how='any')
df_LaptopAZ["Ram"]=df_LaptopAZ["RAM"]
df_LaptopAZ=df_LaptopAZ.drop(columns="RAM")
# Kiểm tra số lượng giá trị thiếu sau khi xóa
print("Số lượng giá trị thiếu sau khi xóa:")
print(df_LaptopAZ.isnull().sum())

df_LaptopAZ
# Out:
# Số lượng giá trị thiếu sau khi xóa:
# Name      0
# CPU       0
# Memory    0
# Size      0
# GPU       0
# Price     0
# Link      0
# Ram       0
# dtype: int64
#                                                   Name  \
# 30   [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...
# 32   [Mới 100%] Lenovo ThinkPad P16 (Core i5-12600H...
# 35   [New 100%] Laptop Dell XPS 13-9300 (Core i5-10...
# 37   [Mới 100%] Laptop Dell XPS 13-9310 (Core i5-11...
# 38   [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...
# ..                                                 ...
# 275  [New 100%] Dell Inspiron 7445 2-in-1 2024 (Ryz...
# 276  [New 100%] HP Envy x360 2-in-1 14-fa0023dx 202...
# 277  [New 100%] Lenovo Legion Y9000P 2024 (Core i9-...
# 278  [New 100%] Lenovo LOQ 2024 15IAX9 (Core i5-124...
# 279  [New 100%] Lenovo LOQ 2024 15ARP9 83JC0001US (...
#
#                                                    CPU  \
# 30              11th Generation Intel® Core™ i7-1165G7
# 32   Intel® Core™ i5-12600HX vPro® Processor (E-cor...
# 35                              Intel® Core™ i5-1035G1
# 37              11th Generation Intel® Core™ i5-1135G7
# 38              11th Generation Intel® Core™ i7-1165G7
# ..                                                 ...
# 275  AMD Ryzen™ 5 8640HS 6-core/12-thread Processor...
# 276  Ryzen 7 8840HS ( 8 Cores, 16 Threads, Turbo 3....
# 277  14th Generation Intel® Core i9-14900HX, 24C / ...
# 278  Intel® Core™ i5-12450HX (2.00GHz up to 4.40GHz...
# 279  AMD Ryzen™ 5-7235HS (3.20GHz up to 4.20GHz, 8M...
#
#                                     Memory  \
# 30               SSD 1TB PCIe NVMe Gen3 x4
# 32                 512GB M.2 PCIe NMVe SSD
# 35                               SSD 256GB
# 37             SSD 256GB PCIe NVMe Gen3 x4
# 38             SSD 512GB PCIe NVMe Gen3 x4
# ..                                     ...
# 275  512GB M.2 PCIe NVMe Solid State Drive
# 276                1TB PCIe® NVMe™ M.2 SSD
# 277                  1TB M.2 PCIe NVMe SSD
# 278   512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®
# 279   512GB SSD M.2 2242 PCIe® 4.0x4 NVMe®
#
#                                                   Size  \
# 30                        13.4 Inch UHD+ (3840 x 2400)
# 32   16.0" WUXGA (1920 x 1200) IPS, anti-glare, 300...
# 35                                   13.4 Inch FHD IPS
# 37                                   13.4 Inch FHD IPS
# 38                                   13.4 Inch FHD IPS
# ..                                                 ...
# 275  14.0-inch 16:10 FHD+ (1920 x 1200) Touch 250ni...
# 276  14" diagonal, FHD+ (1920 x 1200), multitouch-e...
# 277  16" WQXGA (2560×1600) IPS 500nits Anti-glare, ...
# 278  15.6inch FHD (1920x1080) IPS 300nits Anti-glar...
# 279  15.6" FHD (1920x1080) IPS 300nits Anti-glare, ...
#
#                                                    GPU       Price  \
# 30   Intel® Iris® Xe Graphics with shared graphics ...  53.890.000
# 32                          NVIDIA RTX A1000 4GB (95W)  38.000.000
# 35     intel® UHD Graphics with shared graphics memory  27.890.000
# 37   Intel® Iris® Xe Graphics with shared graphics ...  33.890.000
# 38   Intel® Iris® Xe Graphics with shared graphics ...  43.890.000
# ..                                                 ...         ...
# 275                               AMD Radeon™ Graphics  14.590.000
# 276                               AMD Radeon™ Graphics  17.890.000
# 277           NVIDIA GeForce RTX 4060 8GB GDDR6 (140W)  37.890.000
# 278                NVIDIA® GeForce RTX™ 2050 4GB GDDR6  16.990.000
# 279                NVIDIA® GeForce RTX™ 3050 6GB GDDR6  16.490.000
#
#                                                   Link  \
# 30   https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 32   https://laptopaz.vn/lenovo-thinkpad-p16-core-i...
# 35   https://laptopaz.vn/moi-100-laptop-dell-xps-13...
# 37   https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 38   https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# ..                                                 ...
# 275  https://laptopaz.vn/new-100-dell-inspiron-7445...
# 276  https://laptopaz.vn/new-100-hp-envy-x360-2-in-...
# 277  https://laptopaz.vn/new-100-lenovo-legion-y900...
# 278  https://laptopaz.vn/new-100-lenovo-loq-2024-15...
# 279  https://laptopaz.vn/new-100-lenovo-loq-2024-15...
#
#                                                  Ram
# 30                                       16GB LPDDR4
# 32                             32GB DDR5 Bus 4800MHz
# 35                              8GB DDR4 Bus 2400MHz
# 37                                       16GB LPDDR4
# 38                                       16GB LPDDR4
# ..                                               ...
# 275                        8GB, 1x8GB, DDR5, 5600MHz
# 276                              16GB LPDDR5 6400MHz
# 277                                32GB DDR5 5600MHz
# 278                   12GB DDR5 4800MHz (up to 32GB)
# 279  12GB SO-DIMM DDR5-4800MHz (2 slots, up to 32GB)
#
# [203 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder

# 1. Đọc dữ liệu từ file Excel
df_Laptops_anphat = pd.read_excel('Laptops_anphat.xlsx')
df_Laptops_anphat['Link'] = df_Laptops_anphat['Link_laptop-href']
# 2. Xóa các cột không liên quan
columns_to_drop = [
    'web-scraper-order', 'web-scraper-start-url', 'Link_trang', 'Link_trang-href',
    'Link_laptop', 'Link_laptop-href', 'OS_ver', 'Pin', 'Cân nặng', 'Tính năng',
    'Màu sắc', 'Hãng', 'Giá Khuyến mãi'
]
df_Laptops_anphat = df_Laptops_anphat.drop(columns=columns_to_drop)

# 3. Xử lý các giá trị thiếu
# Loại bỏ các hàng có giá trị thiếu
df_Laptops_anphat = df_Laptops_anphat.dropna(how='any')
# Kiểm tra số lượng giá trị thiếu sau khi xóa
print("Số lượng giá trị thiếu sau khi xóa:")
print(df_Laptops_anphat.isnull().sum())
df_Laptops_anphat
# Out:
# Số lượng giá trị thiếu sau khi xóa:
# Tên             0
# CPU             0
# RAM             0
# Ổ Cứng          0
# VGA             0
# Màn hình        0
# giá niêm yết    0
# Link            0
# dtype: int64
#                                                    Tên  \
# 0    Laptop HP Pavilion X360 14-ek1049TU 80R27PA (I...
# 1    Laptop Lenovo Yoga Book 9 13IMU9 83FF001SVN (I...
# 2    Laptop MSI Katana 15 B13VGK-1211VN (Intel Core...
# 3    Laptop HP ProBook 450 G10 9H1N6PT (Intel Core ...
# 4    Laptop Asus Vivobook 14 X1404ZA-NK389W (Intel ...
# ..                                                 ...
# 139  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...
# 140  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...
# 141  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...
# 142  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...
# 143  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...
#
#                                                    CPU  \
# 0       CPU: Intel Core i5-1335U (upto 4.60 GHz, 12MB)
# 1    CPU: Intel Core Ultra 7 155U (up to 4.80GHz, 2...
# 2     CPU: Intel Core i7-13620H (Up to 4.90 GHz, 24MB)
# 3    CPU: Intel Core i7-1355U (up to 5.0 GHz, 12 MB...
# 4        CPU: Intel Core i7-1255U (upto 4.70GHz, 12MB)
# ..                                                 ...
# 139  CPU: Intel Core i7-14650HX (upto 5.20 GHz, 16 ...
# 140  CPU: AMD Ryzen AI 9 HX 370 (36MB Cache, up to ...
# 141  CPU: Intel Core i7-13650HX Processor (upto 4.9...
# 142     CPU: Intel Core i7-1355U (12MB, up to 5.00GHz)
# 143  CPU: Intel Core i5-1335U (up to 4.6 GHz, 12 MB...
#
#                                                    RAM  \
# 0                    RAM: 16GB DDR4-3200 MHz (onboard)
# 1                            RAM: 32GB LPDDR5x-7467MHz
# 2    VGA: NVIDIA GeForce RTX 4070 8GB GDDR6 (AI TOP...
# 3               RAM: 8 GB DDR4-3200 MHz RAM (1 x 8 GB)
# 4            RAM: 8GB DDR4 on board + 8GB DDR4 SO-DIMM
# ..                                                 ...
# 139  VGA: NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 140  RAM: 8GB*2 LPDDR5X 7500 on board (2 khe, tối đ...
# 141             VGA: NVIDIA GeForce RTX 4070 8GB GDDR6
# 142              RAM: 16GB DDR4-3200 MHz RAM (2 x 8GB)
# 143           RAM: 16 GB DDR4-3200 MHz RAM (1 x 16 GB)
#
#                                                 Ổ Cứng  \
# 0                         Ổ cứng: 512 GB SSD NVMe PCIe
# 1           Ổ cứng: 1TB SSD M.2 2242 PCIe® 4.0x4 NVMe®
# 2    Màn hình: 15.6 inch FHD (1920*1080), 144Hz, IP...
# 3                                   Ổ cứng: 512 GB SSD
# 4                           Ổ cứng: 512GB SSD M.2 NVMe
# ..                                                 ...
# 139  Màn hình: 16 inch WQXGA (2560 x 1600) 240Hz DC...
# 140                Ổ cứng: 1TB PCIe® 4.0 NVMe™ M.2 SSD
# 141  Màn hình: 16 inch QHD+ 16:10 (2560 x 1600, WQX...
# 142                 Ổ cứng: 512 GB PCIe® NVMe™ M.2 SSD
# 143                       Ổ cứng: 512 GB PCIe NVMe SSD
#
#                                                    VGA  \
# 0                                   VGA: Intel Iris Xe
# 1                      VGA: Integrated Intel® Graphics
# 2             RAM: 16GB (2 x 8GB) DDR5 5600MHz (2 khe)
# 3                              VGA: Intel UHD Graphics
# 4                          VGA: Intel Iris Xe Graphics
# ..                                                 ...
# 139  RAM: 1*16GB DDR5 (2 khe, tối đa 32GB, cắm sẵn ...
# 140  VGA: NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI T...
# 141                        RAM: 16GB DDR5-4800 SO-DIMM
# 142                           VGA: Intel Intel Iris Xe
# 143                            VGA: Intel UHD Graphics
#
#                                               Màn hình  giá niêm yết  \
# 0    Màn hình: 14 inch FHD (1920 x 1080), IPS, edge...  24.290.000 đ
# 1    Màn hình: 13.3 inch 2.8K(2880x1800) OLED, 400n...  66.990.000 đ
# 2                     Ổ cứng: 1TB NVMe PCIe SSD Gen4x4  44.990.000 đ
# 3    Màn hình: 15.6 inch FHD (1920 x 1080), IPS, na...  25.890.000 đ
# 4    Màn hình: 14 inch FHD (1920 x 1080) 16:9 aspec...  17.990.000 đ
# ..                                                 ...           ...
# 139  Ổ cứng: 1TB PCIe NVMe SED SSD  (nâng cấp tối đ...  46.990.000 đ
# 140  Màn hình: 14 inch 2.5K (2560 x 1600, WQXGA) 16...  44.990.000 đ
# 141              Ổ cứng: 512GB PCIe® 4.0 NVMe™ M.2 SSD  54.990.000 đ
# 142  Màn hình: 14 inch FHD (1920 x 1080), micro-edg...  21.990.000 đ
# 143  Màn hình: 13.3" FHD (1920 x 1080), FHD (1920 x...  24.390.000 đ
#
#                                                   Link
# 0    https://www.anphatpc.com.vn/laptop-hp-pavilion...
# 1    https://www.anphatpc.com.vn/laptop-lenovo-yoga...
# 2    https://www.anphatpc.com.vn/laptop-msi-katana-...
# 3    https://www.anphatpc.com.vn/laptop-hp-probook-...
# 4    https://www.anphatpc.com.vn/laptop-asus-vivobo...
# ..                                                 ...
# 139  https://www.anphatpc.com.vn/laptop-acer-predat...
# 140  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 141  https://www.anphatpc.com.vn/laptop-asus-rog-st...
# 142  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 143  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
# [143 rows x 8 columns]

# %%
import pandas as pd
import random

def preprocess_file(df, column_mapping):

    # Đổi tên các cột theo ánh xạ
    df = df.rename(columns=column_mapping)

    # Chọn các cột cần thiết (nếu cột không tồn tại, thêm cột đó với giá trị mặc định là None)
    required_columns = ['Name', 'Price', 'CPU', 'Ram', 'Memory', 'Size', 'GPU','Link']
    for col in required_columns:
        if col not in df.columns:
            df[col] = None

    # Lưu file kết quả
    df = df[required_columns]  # Đảm bảo đúng thứ tự các cột
    return df

# Ánh xạ tên cột hiện tại về tên chuẩn
column_mapping_anphat = {
    'Tên': 'Name',
    'giá niêm yết': 'Price',
    'CPU': 'CPU',
    'RAM': 'Ram',
    'Ổ Cứng': 'Memory',
    'Màn hình': 'Size',
    'VGA': 'GPU'
}
df_Laptops_anphat=preprocess_file(df_Laptops_anphat,  column_mapping_anphat)
df_Laptops_anphat
# Out:
#                                                   Name         Price  \
# 0    Laptop HP Pavilion X360 14-ek1049TU 80R27PA (I...  24.290.000 đ
# 1    Laptop Lenovo Yoga Book 9 13IMU9 83FF001SVN (I...  66.990.000 đ
# 2    Laptop MSI Katana 15 B13VGK-1211VN (Intel Core...  44.990.000 đ
# 3    Laptop HP ProBook 450 G10 9H1N6PT (Intel Core ...  25.890.000 đ
# 4    Laptop Asus Vivobook 14 X1404ZA-NK389W (Intel ...  17.990.000 đ
# ..                                                 ...           ...
# 139  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46.990.000 đ
# 140  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44.990.000 đ
# 141  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54.990.000 đ
# 142  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21.990.000 đ
# 143  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24.390.000 đ
#
#                                                    CPU  \
# 0       CPU: Intel Core i5-1335U (upto 4.60 GHz, 12MB)
# 1    CPU: Intel Core Ultra 7 155U (up to 4.80GHz, 2...
# 2     CPU: Intel Core i7-13620H (Up to 4.90 GHz, 24MB)
# 3    CPU: Intel Core i7-1355U (up to 5.0 GHz, 12 MB...
# 4        CPU: Intel Core i7-1255U (upto 4.70GHz, 12MB)
# ..                                                 ...
# 139  CPU: Intel Core i7-14650HX (upto 5.20 GHz, 16 ...
# 140  CPU: AMD Ryzen AI 9 HX 370 (36MB Cache, up to ...
# 141  CPU: Intel Core i7-13650HX Processor (upto 4.9...
# 142     CPU: Intel Core i7-1355U (12MB, up to 5.00GHz)
# 143  CPU: Intel Core i5-1335U (up to 4.6 GHz, 12 MB...
#
#                                                    Ram  \
# 0                    RAM: 16GB DDR4-3200 MHz (onboard)
# 1                            RAM: 32GB LPDDR5x-7467MHz
# 2    VGA: NVIDIA GeForce RTX 4070 8GB GDDR6 (AI TOP...
# 3               RAM: 8 GB DDR4-3200 MHz RAM (1 x 8 GB)
# 4            RAM: 8GB DDR4 on board + 8GB DDR4 SO-DIMM
# ..                                                 ...
# 139  VGA: NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 140  RAM: 8GB*2 LPDDR5X 7500 on board (2 khe, tối đ...
# 141             VGA: NVIDIA GeForce RTX 4070 8GB GDDR6
# 142              RAM: 16GB DDR4-3200 MHz RAM (2 x 8GB)
# 143           RAM: 16 GB DDR4-3200 MHz RAM (1 x 16 GB)
#
#                                                 Memory  \
# 0                         Ổ cứng: 512 GB SSD NVMe PCIe
# 1           Ổ cứng: 1TB SSD M.2 2242 PCIe® 4.0x4 NVMe®
# 2    Màn hình: 15.6 inch FHD (1920*1080), 144Hz, IP...
# 3                                   Ổ cứng: 512 GB SSD
# 4                           Ổ cứng: 512GB SSD M.2 NVMe
# ..                                                 ...
# 139  Màn hình: 16 inch WQXGA (2560 x 1600) 240Hz DC...
# 140                Ổ cứng: 1TB PCIe® 4.0 NVMe™ M.2 SSD
# 141  Màn hình: 16 inch QHD+ 16:10 (2560 x 1600, WQX...
# 142                 Ổ cứng: 512 GB PCIe® NVMe™ M.2 SSD
# 143                       Ổ cứng: 512 GB PCIe NVMe SSD
#
#                                                   Size  \
# 0    Màn hình: 14 inch FHD (1920 x 1080), IPS, edge...
# 1    Màn hình: 13.3 inch 2.8K(2880x1800) OLED, 400n...
# 2                     Ổ cứng: 1TB NVMe PCIe SSD Gen4x4
# 3    Màn hình: 15.6 inch FHD (1920 x 1080), IPS, na...
# 4    Màn hình: 14 inch FHD (1920 x 1080) 16:9 aspec...
# ..                                                 ...
# 139  Ổ cứng: 1TB PCIe NVMe SED SSD  (nâng cấp tối đ...
# 140  Màn hình: 14 inch 2.5K (2560 x 1600, WQXGA) 16...
# 141              Ổ cứng: 512GB PCIe® 4.0 NVMe™ M.2 SSD
# 142  Màn hình: 14 inch FHD (1920 x 1080), micro-edg...
# 143  Màn hình: 13.3" FHD (1920 x 1080), FHD (1920 x...
#
#                                                    GPU  \
# 0                                   VGA: Intel Iris Xe
# 1                      VGA: Integrated Intel® Graphics
# 2             RAM: 16GB (2 x 8GB) DDR5 5600MHz (2 khe)
# 3                              VGA: Intel UHD Graphics
# 4                          VGA: Intel Iris Xe Graphics
# ..                                                 ...
# 139  RAM: 1*16GB DDR5 (2 khe, tối đa 32GB, cắm sẵn ...
# 140  VGA: NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI T...
# 141                        RAM: 16GB DDR5-4800 SO-DIMM
# 142                           VGA: Intel Intel Iris Xe
# 143                            VGA: Intel UHD Graphics
#
#                                                   Link
# 0    https://www.anphatpc.com.vn/laptop-hp-pavilion...
# 1    https://www.anphatpc.com.vn/laptop-lenovo-yoga...
# 2    https://www.anphatpc.com.vn/laptop-msi-katana-...
# 3    https://www.anphatpc.com.vn/laptop-hp-probook-...
# 4    https://www.anphatpc.com.vn/laptop-asus-vivobo...
# ..                                                 ...
# 139  https://www.anphatpc.com.vn/laptop-acer-predat...
# 140  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 141  https://www.anphatpc.com.vn/laptop-asus-rog-st...
# 142  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 143  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
# [143 rows x 8 columns]

# %%
df_LaptopAZ_Laptop_anphat = pd.concat([df_LaptopAZ,df_Laptops_anphat], ignore_index=True)
df_LaptopAZ_Laptop_anphat
# Out:
#                                                   Name  \
# 0    [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...
# 1    [Mới 100%] Lenovo ThinkPad P16 (Core i5-12600H...
# 2    [New 100%] Laptop Dell XPS 13-9300 (Core i5-10...
# 3    [Mới 100%] Laptop Dell XPS 13-9310 (Core i5-11...
# 4    [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...
# ..                                                 ...
# 341  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...
# 342  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...
# 343  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...
# 344  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...
# 345  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...
#
#                                                    CPU  \
# 0               11th Generation Intel® Core™ i7-1165G7
# 1    Intel® Core™ i5-12600HX vPro® Processor (E-cor...
# 2                               Intel® Core™ i5-1035G1
# 3               11th Generation Intel® Core™ i5-1135G7
# 4               11th Generation Intel® Core™ i7-1165G7
# ..                                                 ...
# 341  CPU: Intel Core i7-14650HX (upto 5.20 GHz, 16 ...
# 342  CPU: AMD Ryzen AI 9 HX 370 (36MB Cache, up to ...
# 343  CPU: Intel Core i7-13650HX Processor (upto 4.9...
# 344     CPU: Intel Core i7-1355U (12MB, up to 5.00GHz)
# 345  CPU: Intel Core i5-1335U (up to 4.6 GHz, 12 MB...
#
#                                                 Memory  \
# 0                            SSD 1TB PCIe NVMe Gen3 x4
# 1                              512GB M.2 PCIe NMVe SSD
# 2                                            SSD 256GB
# 3                          SSD 256GB PCIe NVMe Gen3 x4
# 4                          SSD 512GB PCIe NVMe Gen3 x4
# ..                                                 ...
# 341  Màn hình: 16 inch WQXGA (2560 x 1600) 240Hz DC...
# 342                Ổ cứng: 1TB PCIe® 4.0 NVMe™ M.2 SSD
# 343  Màn hình: 16 inch QHD+ 16:10 (2560 x 1600, WQX...
# 344                 Ổ cứng: 512 GB PCIe® NVMe™ M.2 SSD
# 345                       Ổ cứng: 512 GB PCIe NVMe SSD
#
#                                                   Size  \
# 0                         13.4 Inch UHD+ (3840 x 2400)
# 1    16.0" WUXGA (1920 x 1200) IPS, anti-glare, 300...
# 2                                    13.4 Inch FHD IPS
# 3                                    13.4 Inch FHD IPS
# 4                                    13.4 Inch FHD IPS
# ..                                                 ...
# 341  Ổ cứng: 1TB PCIe NVMe SED SSD  (nâng cấp tối đ...
# 342  Màn hình: 14 inch 2.5K (2560 x 1600, WQXGA) 16...
# 343              Ổ cứng: 512GB PCIe® 4.0 NVMe™ M.2 SSD
# 344  Màn hình: 14 inch FHD (1920 x 1080), micro-edg...
# 345  Màn hình: 13.3" FHD (1920 x 1080), FHD (1920 x...
#
#                                                    GPU         Price  \
# 0    Intel® Iris® Xe Graphics with shared graphics ...    53.890.000
# 1                           NVIDIA RTX A1000 4GB (95W)    38.000.000
# 2      intel® UHD Graphics with shared graphics memory    27.890.000
# 3    Intel® Iris® Xe Graphics with shared graphics ...    33.890.000
# 4    Intel® Iris® Xe Graphics with shared graphics ...    43.890.000
# ..                                                 ...           ...
# 341  RAM: 1*16GB DDR5 (2 khe, tối đa 32GB, cắm sẵn ...  46.990.000 đ
# 342  VGA: NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI T...  44.990.000 đ
# 343                        RAM: 16GB DDR5-4800 SO-DIMM  54.990.000 đ
# 344                           VGA: Intel Intel Iris Xe  21.990.000 đ
# 345                            VGA: Intel UHD Graphics  24.390.000 đ
#
#                                                   Link  \
# 0    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 1    https://laptopaz.vn/lenovo-thinkpad-p16-core-i...
# 2    https://laptopaz.vn/moi-100-laptop-dell-xps-13...
# 3    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 4    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# ..                                                 ...
# 341  https://www.anphatpc.com.vn/laptop-acer-predat...
# 342  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 343  https://www.anphatpc.com.vn/laptop-asus-rog-st...
# 344  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 345  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                                                    Ram
# 0                                          16GB LPDDR4
# 1                                32GB DDR5 Bus 4800MHz
# 2                                 8GB DDR4 Bus 2400MHz
# 3                                          16GB LPDDR4
# 4                                          16GB LPDDR4
# ..                                                 ...
# 341  VGA: NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 342  RAM: 8GB*2 LPDDR5X 7500 on board (2 khe, tối đ...
# 343             VGA: NVIDIA GeForce RTX 4070 8GB GDDR6
# 344              RAM: 16GB DDR4-3200 MHz RAM (2 x 8GB)
# 345           RAM: 16 GB DDR4-3200 MHz RAM (1 x 16 GB)
#
# [346 rows x 8 columns]

# %%
def fix_columns(row):
    if "Màn hình: " in row['Memory']:
        return {
            'Name': row['Name'],
            'CPU': row['CPU'],
            'Memory': row['Size'],
            'Size': row['Memory'],
            'GPU': row['Ram'],
            'Ram': row['GPU'],
            'Price': row['Price']
        }
    return row



# Áp dụng sửa dữ liệu
df_LaptopAZ_Laptop_anphat = df_LaptopAZ_Laptop_anphat.apply(fix_columns, axis=1, result_type='expand')
df_LaptopAZ_Laptop_anphat
# Out:
#                                                    CPU  \
# 0               11th Generation Intel® Core™ i7-1165G7
# 1    Intel® Core™ i5-12600HX vPro® Processor (E-cor...
# 2                               Intel® Core™ i5-1035G1
# 3               11th Generation Intel® Core™ i5-1135G7
# 4               11th Generation Intel® Core™ i7-1165G7
# ..                                                 ...
# 341  CPU: Intel Core i7-14650HX (upto 5.20 GHz, 16 ...
# 342  CPU: AMD Ryzen AI 9 HX 370 (36MB Cache, up to ...
# 343  CPU: Intel Core i7-13650HX Processor (upto 4.9...
# 344     CPU: Intel Core i7-1355U (12MB, up to 5.00GHz)
# 345  CPU: Intel Core i5-1335U (up to 4.6 GHz, 12 MB...
#
#                                                    GPU  \
# 0    Intel® Iris® Xe Graphics with shared graphics ...
# 1                           NVIDIA RTX A1000 4GB (95W)
# 2      intel® UHD Graphics with shared graphics memory
# 3    Intel® Iris® Xe Graphics with shared graphics ...
# 4    Intel® Iris® Xe Graphics with shared graphics ...
# ..                                                 ...
# 341  VGA: NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 342  VGA: NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI T...
# 343             VGA: NVIDIA GeForce RTX 4070 8GB GDDR6
# 344                           VGA: Intel Intel Iris Xe
# 345                            VGA: Intel UHD Graphics
#
#                                                   Link  \
# 0    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 1    https://laptopaz.vn/lenovo-thinkpad-p16-core-i...
# 2    https://laptopaz.vn/moi-100-laptop-dell-xps-13...
# 3    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# 4    https://laptopaz.vn/laptop-dell-xps-13-9310-co...
# ..                                                 ...
# 341                                                NaN
# 342  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 343                                                NaN
# 344  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 345  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                                                 Memory  \
# 0                            SSD 1TB PCIe NVMe Gen3 x4
# 1                              512GB M.2 PCIe NMVe SSD
# 2                                            SSD 256GB
# 3                          SSD 256GB PCIe NVMe Gen3 x4
# 4                          SSD 512GB PCIe NVMe Gen3 x4
# ..                                                 ...
# 341  Ổ cứng: 1TB PCIe NVMe SED SSD  (nâng cấp tối đ...
# 342                Ổ cứng: 1TB PCIe® 4.0 NVMe™ M.2 SSD
# 343              Ổ cứng: 512GB PCIe® 4.0 NVMe™ M.2 SSD
# 344                 Ổ cứng: 512 GB PCIe® NVMe™ M.2 SSD
# 345                       Ổ cứng: 512 GB PCIe NVMe SSD
#
#                                                   Name         Price  \
# 0    [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...    53.890.000
# 1    [Mới 100%] Lenovo ThinkPad P16 (Core i5-12600H...    38.000.000
# 2    [New 100%] Laptop Dell XPS 13-9300 (Core i5-10...    27.890.000
# 3    [Mới 100%] Laptop Dell XPS 13-9310 (Core i5-11...    33.890.000
# 4    [Mới 100%] Laptop Dell XPS 13-9310 (Core i7-11...    43.890.000
# ..                                                 ...           ...
# 341  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46.990.000 đ
# 342  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44.990.000 đ
# 343  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54.990.000 đ
# 344  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21.990.000 đ
# 345  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24.390.000 đ
#
#                                                    Ram  \
# 0                                          16GB LPDDR4
# 1                                32GB DDR5 Bus 4800MHz
# 2                                 8GB DDR4 Bus 2400MHz
# 3                                          16GB LPDDR4
# 4                                          16GB LPDDR4
# ..                                                 ...
# 341  RAM: 1*16GB DDR5 (2 khe, tối đa 32GB, cắm sẵn ...
# 342  RAM: 8GB*2 LPDDR5X 7500 on board (2 khe, tối đ...
# 343                        RAM: 16GB DDR5-4800 SO-DIMM
# 344              RAM: 16GB DDR4-3200 MHz RAM (2 x 8GB)
# 345           RAM: 16 GB DDR4-3200 MHz RAM (1 x 16 GB)
#
#                                                   Size
# 0                         13.4 Inch UHD+ (3840 x 2400)
# 1    16.0" WUXGA (1920 x 1200) IPS, anti-glare, 300...
# 2                                    13.4 Inch FHD IPS
# 3                                    13.4 Inch FHD IPS
# 4                                    13.4 Inch FHD IPS
# ..                                                 ...
# 341  Màn hình: 16 inch WQXGA (2560 x 1600) 240Hz DC...
# 342  Màn hình: 14 inch 2.5K (2560 x 1600, WQXGA) 16...
# 343  Màn hình: 16 inch QHD+ 16:10 (2560 x 1600, WQX...
# 344  Màn hình: 14 inch FHD (1920 x 1080), micro-edg...
# 345  Màn hình: 13.3" FHD (1920 x 1080), FHD (1920 x...
#
# [346 rows x 8 columns]

# %%
# Xử lý cột CPU để lấy phần chứa "Core" hoặc "Ryzen"
df_LaptopAZ_Laptop_anphat['CPU'] = df_LaptopAZ_Laptop_anphat['CPU'].str.extract(r'(Core.*|Ryzen.*)')
# Xử lý cột Memory để chỉ lấy kích thước (ví dụ: 1TB hoặc 256GB)
df_LaptopAZ_Laptop_anphat['Memory'] = df_LaptopAZ_Laptop_anphat['Memory'].str.extract(r'(\d+[TBGB]+|\d+[ TBGB]+)')

# Xử lý cột Ram để chỉ lấy kích thước RAM (ví dụ: 16GB, 32GB)
df_LaptopAZ_Laptop_anphat['Ram'] = df_LaptopAZ_Laptop_anphat['Ram'].str.extract(r'(\d+GB|\d+ GB)')

# Xử lý cột Size để chỉ lấy kích thước màn hình (ví dụ: 13.4, 16.0)
df_LaptopAZ_Laptop_anphat['Size'] = df_LaptopAZ_Laptop_anphat['Size'].str.extract(r'(\d+\.?\d*)').astype(float)
df_LaptopAZ_Laptop_anphat['Name'] = df_LaptopAZ_Laptop_anphat['Name'].str.replace(r'\[Mới 100%\]|\[New 100%\]', '', regex=True)
df_LaptopAZ_Laptop_anphat['GPU'] = df_LaptopAZ_Laptop_anphat['GPU'].str.replace(r'^VGA:\s*', '', regex=True)
df_LaptopAZ_Laptop_anphat["Price"] = df_LaptopAZ_Laptop_anphat["Price"].str.replace("đ", "").str.replace('.', '', regex=False)  # Bỏ "₫" trong cột Price
df_LaptopAZ_Laptop_anphat["Ram"] = df_LaptopAZ_Laptop_anphat["Ram"].str.replace("GB", "")

# Hiển thị kết quả
df_LaptopAZ_Laptop_anphat
# Out:
#                                                    CPU  \
# 0                                      Core™ i7-1165G7
# 1    Core™ i5-12600HX vPro® Processor (E-cores up t...
# 2                                      Core™ i5-1035G1
# 3                                      Core™ i5-1135G7
# 4                                      Core™ i7-1165G7
# ..                                                 ...
# 341  Core i7-14650HX (upto 5.20 GHz, 16 nhân 24 luồ...
# 342  Ryzen AI 9 HX 370 (36MB Cache, up to 5.1GHz, 1...
# 343    Core i7-13650HX Processor (upto 4.90 GHz, 24MB)
# 344                Core i7-1355U (12MB, up to 5.00GHz)
# 345  Core i5-1335U (up to 4.6 GHz, 12 MB L3 cache, ...
#
#                                                    GPU  \
# 0    Intel® Iris® Xe Graphics with shared graphics ...
# 1                           NVIDIA RTX A1000 4GB (95W)
# 2      intel® UHD Graphics with shared graphics memory
# 3    Intel® Iris® Xe Graphics with shared graphics ...
# 4    Intel® Iris® Xe Graphics with shared graphics ...
# ..                                                 ...
# 341       NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 342  NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI TOPS: ...
# 343                  NVIDIA GeForce RTX 4070 8GB GDDR6
# 344                                Intel Intel Iris Xe
# 345                                 Intel UHD Graphics
#
#                                                   Link   Memory  \
# 0    https://laptopaz.vn/laptop-dell-xps-13-9310-co...      1TB
# 1    https://laptopaz.vn/lenovo-thinkpad-p16-core-i...    512GB
# 2    https://laptopaz.vn/moi-100-laptop-dell-xps-13...    256GB
# 3    https://laptopaz.vn/laptop-dell-xps-13-9310-co...    256GB
# 4    https://laptopaz.vn/laptop-dell-xps-13-9310-co...    512GB
# ..                                                 ...      ...
# 341                                                NaN      1TB
# 342  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...      1TB
# 343                                                NaN    512GB
# 344  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...  512 GB
# 345  https://www.anphatpc.com.vn/laptop-hp-eliteboo...  512 GB
#
#                                                   Name      Price  Ram  Size
# 0     Laptop Dell XPS 13-9310 (Core i7-1165G7, 16GB...   53890000   16  13.4
# 1     Lenovo ThinkPad P16 (Core i5-12600HX, 16GB,  ...   38000000   32  16.0
# 2     Laptop Dell XPS 13-9300 (Core i5-1035G1, 8GB,...   27890000    8  13.4
# 3     Laptop Dell XPS 13-9310 (Core i5-1135G7, 16GB...   33890000   16  13.4
# 4     Laptop Dell XPS 13-9310 (Core i7-1165G7, 16GB...   43890000   16  13.4
# ..                                                 ...        ...  ...   ...
# 341  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46990000    16  16.0
# 342  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000     8  14.0
# 343  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54990000    16  16.0
# 344  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000    16  14.0
# 345  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000   16   13.3
#
# [346 rows x 8 columns]

# %%
df_LaptopAZ_Laptop_anphat.isnull().sum()
# Out:
# CPU        8
# GPU        0
# Link      39
# Memory     2
# Name       0
# Price      0
# Ram        9
# Size       2
# dtype: int64

# %%
df_LaptopAZ_Laptop_anphat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CPU     338 non-null    object
#  1   GPU     346 non-null    object
#  2   Link    307 non-null    object
#  3   Memory  344 non-null    object
#  4   Name    346 non-null    object
#  5   Price   346 non-null    object
#  6   Ram     337 non-null    object
#  7   Size    344 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 21.8+ KB

# %%
memory_data = df_LaptopAZ_Laptop_anphat['Memory'].str.extract(r'(\d+)\s*(GB|TB)', expand=True)
memory_data.dropna(inplace=True)
df_LaptopAZ_Laptop_anphat['Memory'] = memory_data[0].astype(int) * memory_data[1].map({'GB': 1, 'TB': 1024})
# Loại bỏ nội dung trong ngoặc đơn và các dấu cách dư thừa
df_LaptopAZ_Laptop_anphat['CPU'] = df_LaptopAZ_Laptop_anphat['CPU'].str.replace(r'\s*\(.*?\)', '', regex=True).str.strip()

# %%
df_LaptopAZ_Laptop_anphat
# Out:
#                                                 CPU  \
# 0                                   Core™ i7-1165G7
# 1                  Core™ i5-12600HX vPro® Processor
# 2                                   Core™ i5-1035G1
# 3                                   Core™ i5-1135G7
# 4                                   Core™ i7-1165G7
# ..                                              ...
# 341                                 Core i7-14650HX
# 342  Ryzen AI 9 HX 370; AMD Ryzen™ AI up to 81 TOPs
# 343                       Core i7-13650HX Processor
# 344                                   Core i7-1355U
# 345                                   Core i5-1335U
#
#                                                    GPU  \
# 0    Intel® Iris® Xe Graphics with shared graphics ...
# 1                           NVIDIA RTX A1000 4GB (95W)
# 2      intel® UHD Graphics with shared graphics memory
# 3    Intel® Iris® Xe Graphics with shared graphics ...
# 4    Intel® Iris® Xe Graphics with shared graphics ...
# ..                                                 ...
# 341       NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 342  NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI TOPS: ...
# 343                  NVIDIA GeForce RTX 4070 8GB GDDR6
# 344                                Intel Intel Iris Xe
# 345                                 Intel UHD Graphics
#
#                                                   Link  Memory  \
# 0    https://laptopaz.vn/laptop-dell-xps-13-9310-co...  1024.0
# 1    https://laptopaz.vn/lenovo-thinkpad-p16-core-i...   512.0
# 2    https://laptopaz.vn/moi-100-laptop-dell-xps-13...   256.0
# 3    https://laptopaz.vn/laptop-dell-xps-13-9310-co...   256.0
# 4    https://laptopaz.vn/laptop-dell-xps-13-9310-co...   512.0
# ..                                                 ...     ...
# 341                                                NaN  1024.0
# 342  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...  1024.0
# 343                                                NaN   512.0
# 344  https://www.anphatpc.com.vn/laptop-hp-14s-ep01
https://laptop88.vn/new-100-laptop-lenovo-thin...
# 2    https://laptop88.vn/new-100-laptop-lenovo-thin...
# 3    https://laptop88.vn/new-100-laptop-lenovo-thin...
# 4    https://laptop88.vn/new-outlet-laptop-lenovo-l...
# ..                                                 ...
# 139  https://laptop88.vn/new-100-laptop-hp-envy-x36...
# 140  https://laptop88.vn/new-100-dell-inspiron-15-3...
# 141  https://laptop88.vn/new-100-hp-envy-x360-2-in-...
# 142  https://laptop88.vn/new-outlet-laptop-lenovo-f...
# 143  https://laptop88.vn/new-outlet-laptop-lenovo-s...
#
#                                                   Name  \
# 0    [New 100%] Lenovo Legion Y7000P IRX9 83JJ0000C...
# 1    [New 100%] Laptop Lenovo ThinkBook 16 Gen 6 21...
# 2    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 3    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 4    [New Outlet] Laptop Lenovo LOQ 15IAX9 83GS001R...
# ..                                                 ...
# 139  [New 100%] Laptop HP Envy x360 2 in 1 14-fa001...
# 140  [New 100%] Dell Inspiron 15 3530 R4508S / R160...
# 141  [New 100%] HP Envy x360 2 in 1 14-es1023dx 9R8...
# 142  [New Outlet] Laptop Lenovo Flex 7 14IAU8 82Y20...
# 143  [New Outlet] Laptop Lenovo Slim 7 ProX 14IAH7 ...
#
#                         CPU                Ram          Memory  \
# 0    Intel Core i7 -13650HX          24GB DDR5  SSD 512GB NVMe
# 1        AMD Ryzen™ 7 7730U          32GB DDR4    SSD 1TB NVMe
# 2      Intel® Core i7-1355U          16GB DDR5  SSD 512GB NVMe
# 3         AMD Ryzen 5-7530U          16GB DDR4  SSD 512GB NVMe
# 4     Intel Core i5-12450HX          12GB DDR5       SSD 512GB
# ..                      ...                ...             ...
# 139           AMD R5-8640HS        16GB LPDDR5  SSD 512GB NVMe
# 140     Intel Core i5-1334U  8GB DDR4 (R4508S)  SSD 512GB NVMe
# 141      Intel Core 7 -150U          16GB DDR4  SSD 512GB NVMe
# 142   Intel® Core™ i7-1355U        16GB LPDDR4    SSD 1TB NVMe
# 143    Intel Core i7-12700H        16GB LPDDR5  SSD 512GB NVMe
#
#                                      GPU  \
# 0      NVIDIA GeForce RTX 4060 8GB GDDR6
# 1                    AMD Radeon Graphics
# 2                 Intel Iris Xe Graphics
# 3        Integrated AMD Radeon™ Graphics
# 4                     RTX 3050 6GB GDDR6
# ..                                   ...
# 139                AMD   Radeon Graphics
# 140                       Intel Graphics
# 141               Intel Iris Xe Graphics
# 142             Intel® Iris® Xe Graphics
# 143  NVIDIA® GeForce RTX™ 3050 4GB GDDR6
#
#                                             Size        Price  \
# 0              15.6 inch Full HD 144Hz 100% sRGB  29.990.000đ
# 1                           16 inch 2K 100% sRGB  21.590.000đ
# 2                               14 inch Full HD+  21.290.000đ
# 3                               14 inch Full HD+  15.790.000đ
# 4              15.6 inch Full HD 100% sRGB 144Hz  19.690.000đ
# ..                                           ...          ...
# 139                       14 inch Full HD+ Touch  15.590.000đ
# 140                            15.6 Inch Full HD  13.590.000đ
# 141          14 inch Full HD (1920 x 1080) Touch  17.990.000đ
# 142                      14 inch 2.2K, 100% sRGB  15.690.000Đ
# 143  14.5 inch 3K 100% sRGB 400 nits 120Hz Touch  24.590.000đ
#
#                                                   Link
# 0    https://laptop88.vn/new-100-lenovo-legion-y700...
# 1    https://laptop88.vn/new-100-laptop-lenovo-thin...
#
# 116  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 117  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 118  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 119  https://www.ankhang.vn/laptop-asus-vivobook-15...
#
#                                                   Name  \
# 0                      Laptop Gigabyte G5 KF-E3VN333SH
# 1          Laptop Lenovo ThinkPad E16 Gen 1 21JN00GKVA
# 2                      Laptop Dell Inspiron 5440 7FN5J
# 3    Laptop Acer Aspire Lite AL16-51P-55N7 NX.KX0SV...
# 4      Laptop Acer Aspire 3 A314-42P-R3B3 NX.KSFSV.001
# ..                                                 ...
# 115                    Laptop Dell Inspiron 3530 P16WD
# 116             Laptop Asus Vivobook 15 X1504ZA-NJ582W
# 117  Laptop Asus Vivobook 14 X1404ZA-NK386W i3 8GB ...
# 118             Laptop Asus Vivobook 14 X1404ZA-NK389W
# 119        Laptop Asus Vivobook 15 OLED A1505VA-MA468W
#
#                                                    CPU  \
# 0       CPU Intel Core i5-12500H (18MB, up to 4.50GHz)
# 1     CPU Intel® Core™ i5-13420H (12MB, up to 4.6 GHz)
# 2          CPU Intel Core 7 150U (12MB, Up to 5.40GHz)
# 3        CPU Intel Core i5-1235U (12MB, Up to 4.40GHz)
# 4          CPU AMD Ryzen R7-5700U (8MB, up to 4.30GHz)
# ..                                                 ...
# 115      CPU Intel Core i7-1355U (12MB, Up to 5.00GHz)
# 116      CPU Intel Core i3-1215U (10MB, Up to 4.40GHz)
# 117  CPU Intel® Core™ i3-1215U (10MB Cache, up to 4...
# 118  CPU Intel® Core™ i7-1255U (12MB Cache, up to 4...
# 119  CPU Intel® Core™ i5-13500H Processor (18MB cac...
#
#                                   Ram  \
# 0                RAM 8GB DDR4 3200MHz
# 1          RAM 16GB DDR4-3200 (2x8GB)
# 2       RAM 16GB DDR5 5600MHz (2x8GB)
# 3      RAM 16GB DDR5 4800MHz (1x16GB)
# 4    RAM 16GB LPDDR4X 4266MHz onboard
# ..                                ...
# 115             RAM 16GB DDR4 2666MHz
# 116              RAM 8GB DDR4 Onboard
# 117         RAM 8GB DDR4-3200 Onboard
# 118     RAM 16GB DDR4 3200MHz (2x8GB)
# 119             RAM 16GB DDR4 (2x8GB)
#
#                                           Memory  \
# 0                   SSD 512GB M.2 NVMe PCIe Gen4
# 1    SSD 512GB M.2 2242 PCIe 4.0x4 NVMe Opal 2.0
# 2                          SSD 1TB M.2 PCIe NVMe
# 3                            SSD 512GB PCIe NVMe
# 4                            SSD 512GB PCIe NVMe
# ..                                           ...
# 115                        SSD 1TB M.2 PCIe NVMe
# 116                  SSD 512GB M.2 NVMe PCIe 3.0
# 117                SSD 512GB M.2 NVMe™ PCIe® 3.0
# 118                    SSD 512GB M.2 NVMe™ PCIe®
# 119                 SSD 512GB M.2 NVMe™ PCIe 3.0
#
#                                   OS_  \
# 0                  Windows 11 Home SL
# 1                            OS No OS
# 2    OS Windows 11 Home + Office 2021
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 115                               NaN
# 116             OS Windows 11 Home SL
# 117                OS Windows 11 Home
# 118             OS Windows 11 Home SL
# 119                OS Windows 11 Home
#
#                                                   Size  \
# 0                   Display 15.6Inch FHD 144Hz 45%NTSC
# 1    Display 16.0" WUXGA, IPS, 300nits, Anti-glare,...
# 2              Display 14.0Inch FHD+ WVA 250nits 16:10
# 3      Display 16.0inch WUXGA IPS 60Hz 45%NTSC 300nits
# 4               Display 14.0Inch FHD+ IPS 60Hz 45%NTSC
# ..                                                 ...
# 115              Display 15.6Inch FHD 120Hz Anti-Glare
# 116                             VGA Intel UHD Graphics
# 117                            VGA Intel® UHD Graphics
# 118                        VGA Intel® Iris Xe Graphics
# 119  Display 15.6-inch 2.8K OLED 16:9, 0.2ms, 120Hz...
#
#                                                    GPU           Price  \
# 0                VGA NVIDIA GeForce RTX 4060 8GB GDDR6             NaN
# 1                               VGA Intel UHD Graphics  18.990.000 VNĐ
# 2                           VGA Intel Iris Xe Graphics  24.790.000 VNĐ
# 3                               VGA Intel UHD Graphics  12.990.000 VNĐ
# 4                              VGA AMD Radeon Graphics  11.990.000 VNĐ
# ..                                                 ...             ...
# 115                         VGA Intel Iris Xe Graphics  22.490.000 VNĐ
# 116            Display 15.6Inch FHD Anti-Glare 250nits   9.390.000 VNĐ
# 117  Display 14.0 inch FHD (1920x1080) Anti-glare, ...   8.990.000 VNĐ
# 118           Display 14.0" FHD (1920x1080) Anti-glare  14.790.000 VNĐ
# 119                        VGA Intel® Iris Xe Graphics  17.490.000 VNĐ
#
#                                                   Link
# 0    https://www.ankhang.vn/laptop-gigabyte-g5-kf-e...
# 1    https://www.ankhang.vn/laptop-lenovo-thinkpad-...
# 2    https://www.ankhang.vn/laptop-dell-inspiron-54...
# 3    https://www.ankhang.vn/laptop-acer-aspire-lite...
# 4    https://www.ankhang.vn/laptop-acer-aspire-3-a3...
# ..                                                 ...
# 115  https://www.ankhang.vn/laptop-dell-inspiron-35...
# 116  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 117  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 118  https://www.ankhang.vn/laptop-asus-vivobook-x1...
# 119  https://www.ankhang.vn/laptop-asus-vivobook-15...
#
# [120 rows x 15 columns]

# %%
df_laptop88 = df_laptop88.drop(columns=['web-scraper-order','web-scraper-start-url','link_trang','link_trang-href','link_sp','link_sp-href'])
df_Laptop_ankhang = df_Laptop_ankhang.drop(columns=['web-scraper-order','web-scraper-start-url','link_trang','link_trang-href','link_sanpham','link_sanpham-href','OS_'])

# %%
# Xóa tất cả các dòng có ít nhất một giá trị thiếu
df_Laptop_ankhang = df_Laptop_ankhang.dropna(subset=['Size','Price'])
df_laptop88 = df_laptop88.dropna(subset=['Ram','Memory','Price','Size'])

# %%
# Bước 2: Làm sạch dữ liệu trong cột Ram (giữ lại số và loại bỏ ký tự)
df_laptop88['Ram'] = df_laptop88['Ram'].str.extract('(\d+)').astype(int)

# Kiểm tra lại kết quả
print(df_laptop88['Ram'].head())
# Out:
# 0    24
# 1    32
# 2    16
# 3    16
# 4    12
# Name: Ram, dtype: int32

# %%
# Bước 2: Làm sạch dữ liệu trong cột Ram (giữ lại số và loại bỏ ký tự)
df_Laptop_ankhang['Ram'] = df_Laptop_ankhang['Ram'].str.extract('(\d+)').astype(int)

# Kiểm tra lại kết quả
print(df_Laptop_ankhang['Ram'].head())
# Out:
# 1    16
# 2    16
# 3    16
# 4    16
# 5    16
# Name: Ram, dtype: int32

# %%
# Loại bỏ các ký tự không cần thiết trong cột 'Memory' (ví dụ: "GB", "SSD", "NVMe")
df_laptop88['Memory'] = df_laptop88['Memory'].str.extract('(\d+)')

# Thay thế '1TB' bằng '1024GB' trong cột Memory
df_laptop88['Memory'] = df_laptop88['Memory'].replace('1', '1024')
# Kiểm tra dữ liệu sau khi thay thế
print(df_laptop88['Memory'].head())
# Out:
# 0     512
# 1    1024
# 2     512
# 3     512
# 4     512
# Name: Memory, dtype: object

# %%
# Loại bỏ các ký tự không cần thiết trong cột 'Memory' (ví dụ: "GB", "SSD", "NVMe")
df_Laptop_ankhang['Memory'] = df_Laptop_ankhang['Memory'].str.extract('(\d+)')

# Thay thế '1TB' bằng '1024GB' trong cột Memory
df_Laptop_ankhang['Memory'] = df_Laptop_ankhang['Memory'].replace('1', '1024')
# Kiểm tra dữ liệu sau khi thay thế
print(df_Laptop_ankhang['Memory'].head())
# Out:
# 1     512
# 2    1024
# 3     512
# 4     512
# 5     512
# Name: Memory, dtype: object

# %%
import re  # Import the re module for regular expressions

def extract_size(size):
    match = re.search(r'(\d+(\.\d+)?)\s?inch', size, re.IGNORECASE)  # Tìm kích thước theo inch
    if match:
        return float(match.group(1))  # Trả về giá trị số
    return None  # Nếu không tìm thấy, trả về None

# Áp dụng hàm để trích xuất kích thước
df_laptop88['Size'] = df_laptop88['Size'].apply(extract_size)

# Kiểm tra kết quả
print(df_laptop88['Size'])
# Out:
# 0      15.6
# 1      16.0
# 2      14.0
# 3      14.0
# 4      15.6
#        ...
# 139    14.0
# 140    15.6
# 141    14.0
# 142    14.0
# 143    14.5
# Name: Size, Length: 143, dtype: float64

# %%
# Loại bỏ các ký tự không cần thiết trong cột 'SIZE' và chỉ giữ giá trị số
#df1['SIZE'] = df1['SIZE'].str.extract('(\d+(\.\d+)?)')

# Chuyển đổi dữ liệu trong cột 'SIZE' thành kiểu float
#df1['SIZE'] = df1['SIZE'].astype(float)

# Kiểm tra kết quả
#print(df1['SIZE'].head())

# %%
import re  # Import the re module for regular expressions
def extract_size(size):
    match = re.search(r'(\d+(\.\d+)?)\s?inch', size, re.IGNORECASE)  # Tìm kích thước theo inch
    if match:
        return float(match.group(1))  # Trả về giá trị số
    return None  # Nếu không tìm thấy, trả về None

# Áp dụng hàm để trích xuất kích thước
df_Laptop_ankhang['Size'] = df_Laptop_ankhang['Size'].apply(extract_size)
df_Laptop_ankhang = df_Laptop_ankhang.dropna(subset=['Size'])
# Kiểm tra kết quả
print(df_Laptop_ankhang['Size'])
# Out:
# 2      14.0
# 3      16.0
# 4      14.0
# 5      15.6
# 6      15.6
#        ...
# 105    14.0
# 110    15.6
# 113    15.6
# 114    15.6
# 115    15.6
# Name: Size, Length: 82, dtype: float64

# %%
# Loại bỏ các dòng có từ 'liên hệ' trong cột 'price'
df_laptop88 = df_laptop88[df_laptop88['Price'].str.lower() != 'liên hệ']
# Loại bỏ ký tự "đ" và dấu chấm, sau đó chuyển cột 'price' thành số (kiểu float)
#df['Price'] = df['Price'].replace({'đ': '', ',': '', '.': ''}, regex=True).astype(float)
# In kết quả
print(df_laptop88)
# Out:
#                                                   Name  \
# 0    [New 100%] Lenovo Legion Y7000P IRX9 83JJ0000C...
# 1    [New 100%] Laptop Lenovo ThinkBook 16 Gen 6 21...
# 2    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 3    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 4    [New Outlet] Laptop Lenovo LOQ 15IAX9 83GS001R...
# ..                                                 ...
# 139  [New 100%] Laptop HP Envy x360 2 in 1 14-fa001...
# 140  [New 100%] Dell Inspiron 15 3530 R4508S / R160...
# 141  [New 100%] HP Envy x360 2 in 1 14-es1023dx 9R8...
# 142  [New Outlet] Laptop Lenovo Flex 7 14IAU8 82Y20...
# 143  [New Outlet] Laptop Lenovo Slim 7 ProX 14IAH7 ...
#
#                         CPU  Ram Memory                                  GPU  \
# 0    Intel Core i7 -13650HX   24    512    NVIDIA GeForce RTX 4060 8GB GDDR6
# 1        AMD Ryzen™ 7 7730U   32   1024                  AMD Radeon Graphics
# 2      Intel® Core i7-1355U   16    512               Intel Iris Xe Graphics
# 3         AMD Ryzen 5-7530U   16    512      Integrated AMD Radeon™ Graphics
# 4     Intel Core i5-12450HX   12    512                   RTX 3050 6GB GDDR6
# ..                      ...  ...    ...                                  ...
# 139           AMD R5-8640HS   16    512                AMD   Radeon Graphics
# 140     Intel Core i5-1334U    8    512                       Intel Graphics
# 141      Intel Core 7 -150U   16    512               Intel Iris Xe Graphics
# 142   Intel® Core™ i7-1355U   16   1024             Intel® Iris® Xe Graphics
# 143    Intel Core i7-12700H   16    512  NVIDIA® GeForce RTX™ 3050 4GB GDDR6
#
#      Size        Price                                               Link
# 0    15.6  29.990.000đ  https://laptop88.vn/new-100-lenovo-legion-y700...
# 1    16.0  21.590.000đ  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 2    14.0  21.290.000đ  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 3    14.0  15.790.000đ  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 4    15.6  19.690.000đ  https://laptop88.vn/new-outlet-laptop-lenovo-l...
# ..    ...          ...                                                ...
# 139  14.0  15.590.000đ  https://laptop88.vn/new-100-laptop-hp-envy-x36...
# 140  15.6  13.590.000đ  https://laptop88.vn/new-100-dell-inspiron-15-3...
# 141  14.0  17.990.000đ  https://laptop88.vn/new-100-hp-envy-x360-2-in-...
# 142  14.0  15.690.000Đ  https://laptop88.vn/new-outlet-laptop-lenovo-f...
# 143  14.5  24.590.000đ  https://laptop88.vn/new-outlet-laptop-lenovo-s...
#
# [139 rows x 8 columns]

# %%
df_laptop88
# Out:
#                                                   Name  \
# 0    [New 100%] Lenovo Legion Y7000P IRX9 83JJ0000C...
# 1    [New 100%] Laptop Lenovo ThinkBook 16 Gen 6 21...
# 2    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 3    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
#
# 6    CPU Intel Core i7-13620H (24MB, Up to 4.90GHz)   16    512  15.6
# ..                                              ...  ...    ...   ...
# 105  CPU Intel Core i7-13700H (24MB, Up to 5.00GHz)   16   1024  14.0
# 110   CPU Intel Core i3-1305U (10MB, Up to 4.50GHz)    8    512  15.6
# 113   CPU Intel Core i5-1334U (12MB, Up to 4.60GHz)   16    512  15.6
# 114   CPU Intel Core i7-1355U (12MB, Up to 5.00GHz)   16    512  15.6
# 115   CPU Intel Core i7-1355U (12MB, Up to 5.00GHz)   16   1024  15.6
#
#                                        GPU           Price  \
# 2               VGA Intel Iris Xe Graphics  24.790.000 VNĐ
# 3                   VGA Intel UHD Graphics  12.990.000 VNĐ
# 4                  VGA AMD Radeon Graphics  11.990.000 VNĐ
# 5    VGA NVIDIA GeForce RTX 3050 4GB GDDR6  18.490.000 VNĐ
# 6    VGA NVIDIA GeForce RTX 4060 8GB GDDR6  27.490.000 VNĐ
# ..                                     ...             ...
# 105             VGA Intel Iris Xe Graphics  17.490.000 VNĐ
# 110                 VGA Intel UHD Graphics  12.090.000 VNĐ
# 113             VGA Intel Iris Xe Graphics  17.490.000 VNĐ
# 114             VGA Intel Iris Xe Graphics  20.190.000 VNĐ
# 115             VGA Intel Iris Xe Graphics  22.490.000 VNĐ
#
#                                                   Link
# 2    https://www.ankhang.vn/laptop-dell-inspiron-54...
# 3    https://www.ankhang.vn/laptop-acer-aspire-lite...
# 4    https://www.ankhang.vn/laptop-acer-aspire-3-a3...
# 5    https://www.ankhang.vn/laptop-gaming-acer-aspi...
# 6    https://www.ankhang.vn/laptop-msi-cyborg-15-a1...
# ..                                                 ...
# 105  https://www.ankhang.vn/laptop-msi-modern-14-h-...
# 110  https://www.ankhang.vn/laptop-dell-vostro-3530...
# 113  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 114  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 115  https://www.ankhang.vn/laptop-dell-inspiron-35...
#
# [82 rows x 8 columns]

# %%
df_laptop88_Laptop_ankhang = pd.concat([df_laptop88,df_Laptop_ankhang], ignore_index=True)
df_laptop88_Laptop_ankhang
# Out:
#                                                   Name  \
# 0    [New 100%] Lenovo Legion Y7000P IRX9 83JJ0000C...
# 1    [New 100%] Laptop Lenovo ThinkBook 16 Gen 6 21...
# 2    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 3    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 4    [New Outlet] Laptop Lenovo LOQ 15IAX9 83GS001R...
# ..                                                 ...
# 216                 Laptop MSI Modern 14 H D13MG 217VN
# 217                  Laptop Dell Vostro 3530 V5I3465W1
# 218                Laptop Dell Inspiron 15 3530 P16WD2
# 219              Laptop Dell Inspiron 15 3530 71053721
# 220                    Laptop Dell Inspiron 3530 P16WD
#
#                                                 CPU  Ram Memory  \
# 0                            Intel Core i7 -13650HX   24    512
# 1                                AMD Ryzen™ 7 7730U   32   1024
# 2                              Intel® Core i7-1355U   16    512
# 3                                 AMD Ryzen 5-7530U   16    512
# 4                             Intel Core i5-12450HX   12    512
# ..                                              ...  ...    ...
# 216  CPU Intel Core i7-13700H (24MB, Up to 5.00GHz)   16   1024
# 217   CPU Intel Core i3-1305U (10MB, Up to 4.50GHz)    8    512
# 218   CPU Intel Core i5-1334U (12MB, Up to 4.60GHz)   16    512
# 219   CPU Intel Core i7-1355U (12MB, Up to 5.00GHz)   16    512
# 220   CPU Intel Core i7-1355U (12MB, Up to 5.00GHz)   16   1024
#
#                                    GPU  Size           Price  \
# 0    NVIDIA GeForce RTX 4060 8GB GDDR6  15.6     29.990.000đ
# 1                  AMD Radeon Graphics  16.0     21.590.000đ
# 2               Intel Iris Xe Graphics  14.0     21.290.000đ
# 3      Integrated AMD Radeon™ Graphics  14.0     15.790.000đ
# 4                   RTX 3050 6GB GDDR6  15.6     19.690.000đ
# ..                                 ...   ...             ...
# 216         VGA Intel Iris Xe Graphics  14.0  17.490.000 VNĐ
# 217             VGA Intel UHD Graphics  15.6  12.090.000 VNĐ
# 218         VGA Intel Iris Xe Graphics  15.6  17.490.000 VNĐ
# 219         VGA Intel Iris Xe Graphics  15.6  20.190.000 VNĐ
# 220         VGA Intel Iris Xe Graphics  15.6  22.490.000 VNĐ
#
#                                                   Link
# 0    https://laptop88.vn/new-100-lenovo-legion-y700...
# 1    https://laptop88.vn/new-100-laptop-lenovo-thin...
# 2    https://laptop88.vn/new-100-laptop-lenovo-thin...
# 3    https://laptop88.vn/new-100-laptop-lenovo-thin...
# 4    https://laptop88.vn/new-outlet-laptop-lenovo-l...
# ..                                                 ...
# 216  https://www.ankhang.vn/laptop-msi-modern-14-h-...
# 217  https://www.ankhang.vn/laptop-dell-vostro-3530...
# 218  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 219  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 220  https://www.ankhang.vn/laptop-dell-inspiron-35...
#
# [221 rows x 8 columns]

# %%
df_laptop88_Laptop_ankhang['CPU'] = df_laptop88_Laptop_ankhang['CPU'].str.replace('CPU ', '', regex=True).str.replace(r'\s*\(.*?\)', '', regex=True)
df_laptop88_Laptop_ankhang['GPU'] = df_laptop88_Laptop_ankhang['GPU'].str.replace('VGA ', '', regex=True)
df_laptop88_Laptop_ankhang["Price"] = df_laptop88_Laptop_ankhang["Price"].str.replace(" VNĐ", "").str.replace('.', '', regex=False).str.replace('đ', '', regex=False).str.replace('Đ', '', regex=False)
df_laptop88_Laptop_ankhang
# Out:
#                                                   Name  \
# 0    [New 100%] Lenovo Legion Y7000P IRX9 83JJ0000C...
# 1    [New 100%] Laptop Lenovo ThinkBook 16 Gen 6 21...
# 2    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 3    [New 100%] Laptop Lenovo ThinkBook 14 Gen 6 21...
# 4    [New Outlet] Laptop Lenovo LOQ 15IAX9 83GS001R...
# ..                                                 ...
# 216                 Laptop MSI Modern 14 H D13MG 217VN
# 217                  Laptop Dell Vostro 3530 V5I3465W1
# 218                Laptop Dell Inspiron 15 3530 P16WD2
# 219              Laptop Dell Inspiron 15 3530 71053721
# 220                    Laptop Dell Inspiron 3530 P16WD
#
#                         CPU  Ram Memory                                GPU  \
# 0    Intel Core i7 -13650HX   24    512  NVIDIA GeForce RTX 4060 8GB GDDR6
# 1        AMD Ryzen™ 7 7730U   32   1024                AMD Radeon Graphics
# 2      Intel® Core i7-1355U   16    512             Intel Iris Xe Graphics
# 3         AMD Ryzen 5-7530U   16    512    Integrated AMD Radeon™ Graphics
# 4     Intel Core i5-12450HX   12    512                 RTX 3050 6GB GDDR6
# ..                      ...  ...    ...                                ...
# 216    Intel Core i7-13700H   16   1024             Intel Iris Xe Graphics
# 217     Intel Core i3-1305U    8    512                 Intel UHD Graphics
# 218     Intel Core i5-1334U   16    512             Intel Iris Xe Graphics
# 219     Intel Core i7-1355U   16    512             Intel Iris Xe Graphics
# 220     Intel Core i7-1355U   16   1024             Intel Iris Xe Graphics
#
#      Size     Price                                               Link
# 0    15.6  29990000  https://laptop88.vn/new-100-lenovo-legion-y700...
# 1    16.0  21590000  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 2    14.0  21290000  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 3    14.0  15790000  https://laptop88.vn/new-100-laptop-lenovo-thin...
# 4    15.6  19690000  https://laptop88.vn/new-outlet-laptop-lenovo-l...
# ..    ...       ...                                                ...
# 216  14.0  17490000  https://www.ankhang.vn/laptop-msi-modern-14-h-...
# 217  15.6  12090000  https://www.ankhang.vn/laptop-dell-vostro-3530...
# 218  15.6  17490000  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 219  15.6  20190000  https://www.ankhang.vn/laptop-dell-inspiron-15...
# 220  15.6  22490000  https://www.ankhang.vn/laptop-dell-inspiron-35...
#
# [221 rows x 8 columns]

# %% [markdown]
# ## LaptopCC and Phucanh

# %%
import pandas as pd
import random

def preprocess_file(input_path, column_mapping):
    # Đọc file Excel
    df = pd.read_excel(input_path)

    # Đổi tên các cột theo ánh xạ
    df = df.rename(columns=column_mapping)

    # Chọn các cột cần thiết (nếu cột không tồn tại, thêm cột đó với giá trị mặc định là None)
    required_columns = ['Name', 'Price', 'CPU', 'Ram', 'Memory', 'Size', 'OS', 'GPU','Link']
    for col in required_columns:
        if col not in df.columns:
            df[col] = None

    # Điền giá trị cho cột OS nếu bị thiếu
    def assign_os(cpu):
        cpu = str(cpu).lower()
        if 'intel' in cpu or 'amd' in cpu :
            return random.choice(['Windows 10', 'Windows 11'])
        elif 'apple' in cpu:
            return 'MacOS'
        return None

    df['OS'] = df['OS'].fillna(df['CPU'].apply(assign_os))

    # Lưu file kết quả
    df = df[required_columns]  # Đảm bảo đúng thứ tự các cột
    return df

# Ánh xạ tên cột hiện tại về tên chuẩn
column_mapping_tcc = {
    'Name': 'Name',
    'Giá': 'Price',
    'CPU': 'CPU',
    'Ram': 'Ram',
    'Ổ cứng': 'Memory',
    'Size': 'Size',
    'Hệ điều hành': 'OS',
    'VGA': 'GPU',
    'Link_Laptop-href':'Link'
}

column_mapping_phucanh = {
    'Link_laptop': 'Name',
    'Giá niêm yết': 'Price',
    'CPU': 'CPU',
    'Ram': 'Ram',
    'Ổ cứng': 'Memory',
    'Kích thước màn hình': 'Size',
    'hệ điều hành': 'OS',
    'VGA': 'GPU',
    'Link_laptop-href':'Link'
}

# Xử lý file 1
df_laptopcc=preprocess_file('Laptops_laptoptcc.xlsx',  column_mapping_tcc)

# Xử lý file 2
df_laptopphucanh=preprocess_file('Laptops_phucanh.xlsx',  column_mapping_phucanh)

# %%
df_laptopcc
# Out:
#                                                   Name        Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  
#
#                                                  OS  \
# 0                     Hệ điều hành: Windows 11 Home
# 1                     Hệ điều hành: Windows 11 Home
# 2                     Hệ điều hành: Windows 11 Home
# 3                     Hệ điều hành: Windows 11 Home
# 4                     Hệ điều hành: Windows 11 Home
# ..                                              ...
# 175                   Hệ điều hành: Windows 11 Home
# 176  Hệ điều hành: Windows 11 Home + Office Student
# 177                   Hệ điều hành: Windows 11 Home
# 178                   Hệ điều hành: Windows 11 Home
# 179                   Hệ điều hành: Windows 11 Home
#
#                                                    GPU  \
# 0                    Card màn hình: Intel Arc Graphics
# 1      Card màn hình: VGA onboard - Intel UHD Graphics
# 2    Card màn hình: VGA onboard - Intel Iris Xe Gra...
# 3    Card màn hình: VGA Nvidia - Nvidia GeForce RTX...
# 4      Card màn hình: VGA onboard - Intel UHD Graphics
# ..                                                 ...
# 175    Card màn hình: VGA onboard - Intel UHD Graphics
# 176    Card màn hình: VGA onboard - Intel UHD Graphics
# 177    Card màn hình: VGA onboard - Intel UHD Graphics
# 178  Card màn hình: VGA Intel Iris - Intel Iris Xe ...
# 179  Card màn hình: VGA onboard - Intel Iris Xe Gra...
#
#                                                   Link
# 0    https://www.phucanh.vn/laptop-acer-swift-go-ai...
# 1    https://www.phucanh.vn/laptop-hp-14-ep1009tu-9...
# 2    https://www.phucanh.vn/laptop-lenovo-thinkbook...
# 3    https://www.phucanh.vn/laptop-msi-gaming-katan...
# 4    https://www.phucanh.vn/laptop-acer-aspire-gami...
# ..                                                 ...
# 175  https://www.phucanh.vn/laptop-asus-vivobook-14...
# 176  https://www.phucanh.vn/laptop-dell-inspiron-35...
# 177  https://www.phucanh.vn/laptop-lenovo-ideapad-s...
# 178  https://www.phucanh.vn/laptop-hp-14s-ep0112tu-...
# 179  https://www.phucanh.vn/laptop-hp-pavilion-x360...
#
# [180 rows x 9 columns]

# %%
# # Thay thế giá trị thiếu trong cột OS
# os_values = ['Windows 10', 'Windows 11']
# df_laptopcc['OS'] = df_laptopcc['OS'].apply(lambda x: random.choice(os_values) if pd.isna(x) or x.strip() == '' else x)
df_laptopcc=df_laptopcc.drop(columns="OS")

# %%
df_laptopcc = df_laptopcc[~df_laptopcc.index.duplicated(keep='first')]
df_laptopcc = df_laptopcc.loc[:, ~df_laptopcc.columns.duplicated()]

# %%
# print(df_laptopcc.index.duplicated().any())  # Kiểm tra chỉ mục trùng lặp
# print(df_laptopcc.columns.duplicated().any())  # Kiểm tra cột trùng lặp

# %%
def fix_columns(row):
    if "Ram" in row['CPU'] or "RAM" in row['CPU']:
        return {
            'Name': row['Name'],
            'Price': row['Price'],
            'CPU': None,
            'Ram': row['CPU'],
            'Memory': row['Ram'],
            'Size': row['Memory'],
            'GPU': row['Size'],
            'Link':row['Link'],
        }
    return row



# Áp dụng sửa dữ liệu
df_laptopcc = df_laptopcc.apply(fix_columns, axis=1, result_type='expand')

# # Thay thế giá trị thiếu trong cột OS
# os_values = ['Windows 10', 'Windows 11']
# df_laptopcc['OS'] = df_laptopcc['OS'].apply(lambda x: random.choice(os_values) if pd.isna(x) or x.strip() == '' else x)

# Kiểm tra dữ liệu sau khi sửa
print("\nDữ liệu sau khi sửa:")
df_laptopcc
# Out:
# Dữ liệu sau khi sửa:
#                                                   Name        Price   CPU  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  
https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 274       https://laptoptcc.com/new-dell-inspiron-5410
# 275     https://laptoptcc.com/new-dell-inspiron-5410-1
# 276  https://laptoptcc.com/laptop-cu-hp-elitebook-8...
# 277  https://laptoptcc.com/lenovo-legion-5-r7000-ap...
# 278  https://laptoptcc.com/laptop-cu-dell-inspiron-...
#
# [279 rows x 8 columns]

# %%
# import re

# def extract_cpu_from_name(row):
#     name = row["Name"]

#     # Regex tìm cụm CPU, bao gồm số, thông tin trong ngoặc đơn, và dừng tại `,` hoặc `|`
#     match = re.search(r'(Core[\w\s\-\*]+\d+[A-Z0-9]*\s?\(?.*?\)?|Ryzen[\w\s\-]+\d+[A-Z0-9]*\s?\(?.*?\)?|Pentium[\w\s\-]+\d*[A-Z0-9]*|Core™[\w\s\-]+\d+[A-Z0-9]*|Ryzen™[\w\s\-]+\d+[A-Z0-9]*)(?=\s?[,\|])', name)
#     if match:
#         return match.group(1).strip()  # Lấy thông tin CPU đã tìm thấy
#     return row["CPU"]  # Trả về giá trị CPU gốc nếu không tìm thấy thông tin mới

# # Áp dụng hàm trích xuất vào từng dòng
# df_laptopcc["CPU"] = df_laptopcc.apply(extract_cpu_from_name, axis=1)

# df_laptopcc

# %%
import re

def extract_cpu_from_name(row):
    name = row["Name"]

    # Regex tìm cụm CPU, bao gồm cả số và thông tin trong ngoặc đơn
    match = re.search(r'(Core[\w\s\-\*]+\d+[A-Z0-9]*\s?\(?.*?\)?|Ryzen[\w\s\-]+\d+[A-Z0-9]*|Pentium[\w\s\-]+\d*[A-Z0-9]*|Core™[\w\s\-]+\d+[A-Z0-9]*)', name)
    if match:
        return match.group(1).strip()  # Lấy thông tin CPU đã tìm thấy
    return row["CPU"]  # Trả về giá trị CPU gốc nếu không tìm thấy thông tin mới

# Áp dụng hàm trích xuất vào từng dòng
df_laptopcc["CPU"] = df_laptopcc.apply(extract_cpu_from_name, axis=1)

df_laptopcc
# Out:
#                                                   Name        Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10.500.000đ
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10.500.000đ
# 2    Laptop Cũ Dell XPS 13 9370 |i5-8250U | Ram 8GB...   9.500.000đ
# 3    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11.500.000đ
# 4    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10.900.000đ
# ..                                                 ...          ...
# 274                                 Dell Inspiron 5410  13.500.000đ
# 275                                 Dell Inspiron 5410  14.500.000đ
# 276  Laptop Cũ HP EliteBook 840 G6 Core i7 8565U  /...   8.500.000đ
# 277  Lenovo Legion 5 R7000 APH9 (2024) Ryzen 7-8745...  25.500.000đ
# 278  Laptop Cũ Dell Inspiron 5577 Gaming Core™ i7-7...   9.500.000đ
#
#                  CPU                      Ram  \
# 0      Core i7-8550U     Ram 8GB DDR4 2666MHz
# 1     Core i7- 7500U     Ram 8GB DDR4 2666MHz
# 2               None                  Ram 8GB
# 3            Core i7                 Ram 16GB
# 4      Core I5*8265U   Ram 8GB LPDDR3 2133MHz
# ..               ...                      ...
# 274             None            Ram 16GB DDR4
# 275             None            Ram 16GB DDR4
# 276    Core i7 8565U             Ram 8GB DDR4
# 277    Ryzen 7-8745H  Ram: 16 GB DDR5 5600MHz
# 278  Core™ i7-7700HQ             Ram 8GB DDR4
#
#                                     Memory  \
# 0                         Ổ cứng M.2 256GB
# 1                         Ổ cứng M.2 256GB
# 2                    Ổ cứng 256GB NVMe SSD
# 3                    Ổ cứng 256GB NVMe SSD
# 4                         Ổ cứng SSD 256GB
# ..                                     ...
# 274                           Ổ cứng 512GB
# 275                           Ổ cứng 512GB
# 276                       Ổ cứng SSD 256GB
# 277  Ổ Cứng: 512GB PCIe NVMe M.2 SSD Gen 4
# 278           Ổ cứng SSD 128GB + HDD 500GB
#
#                                                   Size  \
# 0                    Màn hình 13.3 Full HD 1920 x 1080
# 1                               Màn hình 13.3 3K TOUCH
# 2                  Màn hình 13.3 inch, FHD (1920×1080)
# 3                  Màn hình 13.3 inch, FHD (1920×1080)
# 4                                   Màn hình 13.3" FHD
# ..                                                 ...
# 274                                 Màn hình 14.0" FHD
# 275                                 Màn hình 14.0" FHD
# 276                               Màn hình 14" FHD IPS
# 277  Màn hình: 15.6" (1920x1080) IPS, 300nits, 100%...
# 278              Màn hình 15.6" Full HD ( IPS + 600K )
#
#                                                    GPU  \
# 0                            VGA Intel HD Graphics 620
# 1                            VGA Intel HD Graphics 620
# 2                           VGA Intel UHD Graphics 620
# 3                           VGA Intel UHD Graphics 620
# 4                           VGA Intel UHD Graphics 620
# ..                                                 ...
# 274                                  VGA Intel Iris Xe
# 275                                  VGA Intel Iris Xe
# 276                        VGA Intel® UHD Graphics 620
# 277  Card đồ họa: NVIDIA Geforce RTX 4060 8GB GDDR6...
# 278                             VGA GTX 1050 4GB GDDR5
#
#                                                   Link
# 0    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2    https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3    https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 4    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 274       https://laptoptcc.com/new-dell-inspiron-5410
# 275     https://laptoptcc.com/new-dell-inspiron-5410-1
# 276  https://laptoptcc.com/laptop-cu-hp-elitebook-8...
# 277  https://laptoptcc.com/lenovo-legion-5-r7000-ap...
# 278  https://laptoptcc.com/laptop-cu-dell-inspiron-...
#
# [279 rows x 8 columns]

# %%
# import re
# def extract_cpu_from_name(row):
#     name = row["Name"]

#     # Sử dụng regex để tìm cụm từ bắt đầu với "Core" hoặc "Ryzen" đến ký tự "/"
#     match = re.search(r'(Core[\w\s\-]+|Ryzen[\w\s\-]+|Pentium[\w\s\-]+|Core™[\w\s\-]+)(?=\s?/)', name)
#     if match:
#         return match.group(1).strip()  # Lấy phần thông tin CPU đã tìm thấy
#     return row["CPU"]  # Trả về giá trị CPU gốc nếu không tìm thấy thông tin mới

# # Áp dụng hàm trích xuất vào từng dòng
# df_laptopcc["CPU"] = df_laptopcc.apply(extract_cpu_from_name, axis=1)

# df_laptopcc

# %%
import re
def extract_cpu_from_name(row):
    name = row["Name"]

    # Sử dụng regex để tìm cụm từ bắt đầu với "Core" hoặc "Ryzen" đến ký tự "/"
    match = re.search(r'(Core[\w\s\-]+|Ryzen[\w\s\-]+|Pentium[\w\s\-]+|Core™[\w\s\-]+|Ryzen™[\w\s\-]+)(?=\s?[,\|])', name)
    if match:
        return match.group(1).strip()  # Lấy phần thông tin CPU đã tìm thấy
    return row["CPU"]  # Trả về giá trị CPU gốc nếu không tìm thấy thông tin mới

# Áp dụng hàm trích xuất vào từng dòng
df_laptopcc["CPU"] = df_laptopcc.apply(extract_cpu_from_name, axis=1).str.replace(r"\(", "", regex=True)

df_laptopcc
# Out:
#                                                   Name        Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10.500.000đ
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  
https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 274       https://laptoptcc.com/new-dell-inspiron-5410
# 275     https://laptoptcc.com/new-dell-inspiron-5410-1
# 276  https://laptoptcc.com/laptop-cu-hp-elitebook-8...
# 277  https://laptoptcc.com/lenovo-legion-5-r7000-ap...
# 278  https://laptoptcc.com/laptop-cu-dell-inspiron-...
#
# [279 rows x 8 columns]

# %%
# import re
# def extract_cpu_from_name(row):
#     name = row["Name"]

#     # Sử dụng regex để tìm cụm từ bắt đầu với "Core" hoặc "Ryzen" đến ký tự "/"
#     match = re.search(r'(Core[\w\s\-]+|Ryzen[\w\s\-]+|Pentium[\w\s\-]+|Core™[\w\s\-]+)(?=\s?|)', name)
#     if match:
#         return match.group(1).strip()  # Lấy phần thông tin CPU đã tìm thấy
#     return row["CPU"]  # Trả về giá trị CPU gốc nếu không tìm thấy thông tin mới

# # Áp dụng hàm trích xuất vào từng dòng
# df_laptopcc["CPU"] = df_laptopcc.apply(extract_cpu_from_name, axis=1)

# df_laptopcc

# %%
df=df_laptopcc.dropna()
df
# Out:
#                                                   Name        Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10.500.000đ
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10.500.000đ
# 3    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11.500.000đ
# 4    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10.900.000đ
# 5    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12.900.000đ
# ..                                                 ...          ...
# 272  Lenovo ThinkPad X1 Carbon Gen 8  Core i5 10210...  11.800.000đ
# 273  Lenovo Thinkpad X1 Carbon Gen 9 Core i5 - 1135...  14.800.000đ
# 276  Laptop Cũ HP EliteBook 840 G6 Core i7 8565U  /...   8.500.000đ
# 277  Lenovo Legion 5 R7000 APH9 (2024) Ryzen 7-8745...  25.500.000đ
# 278  Laptop Cũ Dell Inspiron 5577 Gaming Core™ i7-7...   9.500.000đ
#
#                   CPU                      Ram  \
# 0       Core i7-8550U     Ram 8GB DDR4 2666MHz
# 1      Core i7- 7500U     Ram 8GB DDR4 2666MHz
# 3             Core i7                 Ram 16GB
# 4       Core I5*8265U   Ram 8GB LPDDR3 2133MHz
# 5      Core i7- 8565U  Ram 16GB LPDDR3 2133MHz
# ..                ...                      ...
# 272    Core i5 10210U    Ram 16GB DDR4 2666MHz
# 273  Core i5 - 1135G7                  Ram 8GB
# 276     Core i7 8565U             Ram 8GB DDR4
# 277     Ryzen 7-8745H  Ram: 16 GB DDR5 5600MHz
# 278   Core™ i7-7700HQ             Ram 8GB DDR4
#
#                                     Memory  \
# 0                         Ổ cứng M.2 256GB
# 1                         Ổ cứng M.2 256GB
# 3                    Ổ cứng 256GB NVMe SSD
# 4                         Ổ cứng SSD 256GB
# 5                         Ổ cứng SSD 256GB
# ..                                     ...
# 272    Ổ cứng M.2 256GB PCIe NVMe Class 35
# 273                       Ổ cứng SSD 256GB
# 276                       Ổ cứng SSD 256GB
# 277  Ổ Cứng: 512GB PCIe NVMe M.2 SSD Gen 4
# 278           Ổ cứng SSD 128GB + HDD 500GB
#
#                                                   Size  \
# 0                    Màn hình 13.3 Full HD 1920 x 1080
# 1                               Màn hình 13.3 3K TOUCH
# 3                  Màn hình 13.3 inch, FHD (1920×1080)
# 4                                   Màn hình 13.3" FHD
# 5                                    Màn hình 13.3" 4K
# ..                                                 ...
# 272           Màn hình 14.0" Full HD IPS (1920 x 1080)
# 273                                Màn hình 14.0" FHD+
# 276                               Màn hình 14" FHD IPS
# 277  Màn hình: 15.6" (1920x1080) IPS, 300nits, 100%...
# 278              Màn hình 15.6" Full HD ( IPS + 600K )
#
#                                                    GPU  \
# 0                            VGA Intel HD Graphics 620
# 1                            VGA Intel HD Graphics 620
# 3                           VGA Intel UHD Graphics 620
# 4                           VGA Intel UHD Graphics 620
# 5                           VGA Intel UHD Graphics 620
# ..                                                 ...
# 272                 VGA Intel® Integrated UHD Graphics
# 273                        VGA Intel Graphics Xe (4gb)
# 276                        VGA Intel® UHD Graphics 620
# 277  Card đồ họa: NVIDIA Geforce RTX 4060 8GB GDDR6...
# 278                             VGA GTX 1050 4GB GDDR5
#
#                                                   Link
# 0    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 3    https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 4    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 5    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 272  https://laptoptcc.com/lenovo-thinkpad-x1-carbo...
# 273  https://laptoptcc.com/lenovo-thinkpad-x1-carbo...
# 276  https://laptoptcc.com/laptop-cu-hp-elitebook-8...
# 277  https://laptoptcc.com/lenovo-legion-5-r7000-ap...
# 278  https://laptoptcc.com/laptop-cu-dell-inspiron-...
#
# [240 rows x 8 columns]

# %%
# Loại bỏ VGA trong cột GPU
df['GPU'] = df['GPU'].str.replace('VGA', '', regex=True)
df['GPU'] = df['GPU'].str.replace('Card đồ họa:', '', regex=True)
df['GPU'] = df['GPU'].str.replace('Card đồ hoạ:', '', regex=True)
df['GPU'] = df['GPU'].str.replace(':', '', regex=True)
# Lấy chỉ số dung lượng từ cột Memory
def extract_memory_size(memory):
    match = re.search(r'(\d+GB)', memory)
    return match.group(1) if match else None

df['Memory'] = df['Memory'].apply(extract_memory_size)
# Gán giá trị xuất hiện nhiều nhất cho Memory bị thiếu
most_common_memory = df['Memory'].mode()[0]
df['Memory'] = df['Memory'].fillna(most_common_memory)
# Lấy chỉ số từ cột Ram
def extract_ram_size(ram):
    match = re.search(r'(\d+)', ram)
    return match.group(1) if match else None

df['Ram'] = df['Ram'].apply(extract_ram_size)

# Lấy chỉ số từ cột Size
def extract_size(size):
    match = re.search(r'(\d+\.\d+|\d+)', size)
    return match.group(1) if match else None

df['Size'] = df['Size'].apply(extract_size)
# Gán những nơi giá tiền "Liên hệ" theo GPU
# df['Price'] = df['Price'].apply(lambda x: 'Liên hệ' if x == 'Liên hệ' else x)
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GPU'] = df['GPU'].str.replace('VGA', '', regex=True)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GPU'] = df['GPU'].str.replace('Card đồ họa:', '', regex=True)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GPU'] = df['GPU'].str.replace('Card đồ hoạ:', '', regex=True)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GPU'] = df['GPU'].str.replace(':', '', regex=True)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].apply(extract_memory_size)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].fillna(most_common_memory)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram'] = df['Ram'].apply(extract_ram_size)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\2164611943.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size'] = df['Size'].apply(extract_size)

# %%
# Loai bo ky tu '-' va khoang trong trong DataFrame
# df['GPU'] = df['GPU'].replace({'-': '', ' ': ''}, regex=True)
# df['CPU'] = df['CPU'].replace({'-': '', ' ': ''}, regex=True)
# Bo cot CPU neu ngan hon 8 ky tu hoac dai hon 14 ky tu
# df = df[df['CPU'].str.len().between(8, 14)]

# %%
# Giả sử df là DataFrame của bạn
df = df[~df['Price'].isin(['Liên hệ', '0đ'])]

# %%
df
# Out:
#                                                   Name        Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10.500.000đ
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10.500.000đ
# 3    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11.500.000đ
# 4    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10.900.000đ
# 5    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12.900.000đ
# ..                                                 ...          ...
# 272  Lenovo ThinkPad X1 Carbon Gen 8  Core i5 10210...  11.800.000đ
# 273  Lenovo Thinkpad X1 Carbon Gen 9 Core i5 - 1135...  14.800.000đ
# 276  Laptop Cũ HP EliteBook 840 G6 Core i7 8565U  /...   8.500.000đ
# 277  Lenovo Legion 5 R7000 APH9 (2024) Ryzen 7-8745...  25.500.000đ
# 278  Laptop Cũ Dell Inspiron 5577 Gaming Core™ i7-7...   9.500.000đ
#
#                   CPU Ram Memory  Size  \
# 0       Core i7-8550U   8  256GB  13.3
# 1      Core i7- 7500U   8  256GB  13.3
# 3             Core i7  16  256GB  13.3
# 4       Core I5*8265U   8  256GB  13.3
# 5      Core i7- 8565U  16  256GB  13.3
# ..                ...  ..    ...   ...
# 272    Core i5 10210U  16  256GB  14.0
# 273  Core i5 - 1135G7   8  256GB  14.0
# 276     Core i7 8565U   8  256GB    14
# 277     Ryzen 7-8745H  16  512GB  15.6
# 278   Core™ i7-7700HQ   8  128GB  15.6
#
#                                            GPU  \
# 0                        Intel HD Graphics 620
# 1                        Intel HD Graphics 620
# 3                       Intel UHD Graphics 620
# 4                       Intel UHD Graphics 620
# 5                       Intel UHD Graphics 620
# ..                                         ...
# 272             Intel® Integrated UHD Graphics
# 273                    Intel Graphics Xe (4gb)
# 276                    Intel® UHD Graphics 620
# 277   NVIDIA Geforce RTX 4060 8GB GDDR6 (125W)
# 278                         GTX 1050 4GB GDDR5
#
#                                                   Link
# 0    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 3    https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 4    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 5    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 272  https://laptoptcc.com/lenovo-thinkpad-x1-carbo...
# 273  https://laptoptcc.com/lenovo-thinkpad-x1-carbo...
# 276  https://laptoptcc.com/laptop-cu-hp-elitebook-8...
# 277  https://laptoptcc.com/lenovo-legion-5-r7000-ap...
# 278  https://laptoptcc.com/laptop-cu-dell-inspiron-...
#
# [219 rows x 8 columns]

# %%
df["Memory"] = df["Memory"].apply(lambda x: int(x.replace("GB", "")) if "GB" in x else int(x.replace("TB", "")) * 1024)

# 2. Loại bỏ chữ 'đ' trong cột Price
df['Price'] = df['Price'].str.replace('đ', '', regex=False).str.replace('.', '', regex=False)
# # 3. Chuyển cột CPU và GPU thành dạng one-hot encoding
# df = pd.get_dummies(df, columns=['CPU', 'GPU'])
# # Bỏ cột OS
# df = df.drop(columns=['OS'])
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\720507048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"] = df["Memory"].apply(lambda x: int(x.replace("GB", "")) if "GB" in x else int(x.replace("TB", "")) * 1024)
# C:\Users\MSI\AppData\Local\Temp\ipykernel_12284\720507048.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].str.replace('đ', '', regex=False).str.replace('.', '', regex=False)

# %%
df
# Out:
#                                                   Name     Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10500000
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10500000
# 3    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11500000
# 4    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  
Hz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR4 3200
# 2     Bộ VXL: Core i7 1355U 1.7GHz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR5 5200
# 3    Bộ VXL: Core i7-13620H 2.4GHz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR5 5200
# 4    Bộ VXL: Core i7 12650H 3.5GHz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR4 3200
# ..                             ...                                      ...
# 175   Bộ VXL: Core i3 1215U 1.2GHz      Bộ nhớ RAM: 8Gb (Onboard) DDR4 3200
# 176   Bộ VXL: Core i5 1235U 1.3GHz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR4 3200
# 177  Bộ VXL: Core i5 12450H 3.3GHz     Bộ nhớ RAM: 16Gb (Onboard) DDR5 4800
# 178   Bộ VXL: Core i5 1335U 1.3GHz       Bộ nhớ RAM: 16Gb (2x8Gb) DDR4 3200
# 179   Bộ VXL: Core i5 1335U 1.3GHz     Bộ nhớ RAM: 16Gb (Onboard) DDR4 3200
#
#                 Memory                                           Size  \
# 0    Ổ cứng: 512Gb SSD             Kích thước màn hình: 14.0inch 2.8K
# 1      Ổ cứng: 1TB SSD          Kích thước màn hình: 14.0inch Full HD
# 2    Ổ cứng: 512Gb SSD            Kích thước màn hình: 14.0inch WUXGA
# 3      Ổ cứng: 1TB SSD          Kích thước màn hình: 15.6inch Full HD
# 4    Ổ cứng: 512Gb SSD          Kích thước màn hình: 15.6inch Full HD
# ..                 ...                                            ...
# 175  Ổ cứng: 512Gb SSD                  Kích thước màn hình: 14.0inch
# 176  Ổ cứng: 512Gb SSD          Kích thước màn hình: 15.6inch Full HD
# 177  Ổ cứng: 512Gb SSD          Kích thước màn hình: 14.0inch Full HD
# 178  Ổ cứng: 512Gb SSD          Kích thước màn hình: 14.0inch Full HD
# 179  Ổ cứng: 512Gb SSD  Kích thước màn hình: 14.0inch FHD TouchScreen
#
#                                                  OS  \
# 0                     Hệ điều hành: Windows 11 Home
# 1                     Hệ điều hành: Windows 11 Home
# 2                     Hệ điều hành: Windows 11 Home
# 3                     Hệ điều hành: Windows 11 Home
# 4                     Hệ điều hành: Windows 11 Home
# ..                                              ...
# 175                   Hệ điều hành: Windows 11 Home
# 176  Hệ điều hành: Windows 11 Home + Office Student
# 177                   Hệ điều hành: Windows 11 Home
# 178                   Hệ điều hành: Windows 11 Home
# 179                   Hệ điều hành: Windows 11 Home
#
#                                                    GPU  \
# 0                    Card màn hình: Intel Arc Graphics
# 1      Card màn hình: VGA onboard - Intel UHD Graphics
# 2    Card màn hình: VGA onboard - Intel Iris Xe Gra...
# 3    Card màn hình: VGA Nvidia - Nvidia GeForce RTX...
# 4      Card màn hình: VGA onboard - Intel UHD Graphics
# ..                                                 ...
# 175    Card màn hình: VGA onboard - Intel UHD Graphics
# 176    Card màn hình: VGA onboard - Intel UHD Graphics
# 177    Card màn hình: VGA onboard - Intel UHD Graphics
# 178  Card màn hình: VGA Intel Iris - Intel Iris Xe ...
# 179  Card màn hình: VGA onboard - Intel Iris Xe Gra...
#
#                                                   Link
# 0    https://www.phucanh.vn/laptop-acer-swift-go-ai...
# 1    https://www.phucanh.vn/laptop-hp-14-ep1009tu-9...
# 2    https://www.phucanh.vn/laptop-lenovo-thinkbook...
# 3    https://www.phucanh.vn/laptop-msi-gaming-katan...
# 4    https://www.phucanh.vn/laptop-acer-aspire-gami...
# ..                                                 ...
# 175  https://www.phucanh.vn/laptop-asus-vivobook-14...
# 176  https://www.phucanh.vn/laptop-dell-inspiron-35...
# 177  https://www.phucanh.vn/laptop-lenovo-ideapad-s...
# 178  https://www.phucanh.vn/laptop-hp-14s-ep0112tu-...
# 179  https://www.phucanh.vn/laptop-hp-pavilion-x360...
#
# [180 rows x 9 columns]

# %%
# Xử lý dữ liệu
df_laptopphucanh["Price"] = df_laptopphucanh["Price"].str.replace(" ₫", "").str.replace('.', '', regex=False)  # Bỏ "₫" trong cột Price
df_laptopphucanh["CPU"] = df_laptopphucanh["CPU"].str.replace("Bộ VXL: ", "")  # Bỏ "Bộ VXL: " trong cột CPU
df_laptopphucanh["Ram"] = df_laptopphucanh["Ram"].str.replace("Bộ nhớ RAM: ", "").str.extract(r"(\d+)")  # Chỉ lấy số trong cột Ram
df_laptopphucanh["Memory"] = df_laptopphucanh["Memory"].str.replace("Ổ cứng: ", "").str.extract(r"(\d+)")  # Lấy số trong cột Memory
df_laptopphucanh["Memory"] = df_laptopphucanh["Memory"].replace("1", "1024")  # Thay "1" bằng "1024"
df_laptopphucanh["Size"] = df_laptopphucanh["Size"].str.extract(r"(\d+\.\d+)")  # Lấy chỉ số kích thước màn hình
df_laptopphucanh["GPU"] = df_laptopphucanh["GPU"].str.replace("Card màn hình: ", "").str.replace("VGA onboard - ", "").str.replace("VGA ", "").str.replace("Nvidia - ", "").str.replace("Intel Iris - ", "")  # Bỏ các từ không cần thiết trong GPU
df_laptopphucanh = df_laptopphucanh.drop(columns=["OS"])  # Bỏ cột OS
df_laptopphucanh
# Out:
#                                                   Name     Price  \
# 0    Laptop Acer Swift Go AI 2024 SFG14-73-53X7 NX....  23990000
# 1    Laptop HP 14 ep1009TU 9Z2W2PA (Core 5 120U/ 16...  23990000
# 2    Laptop Lenovo ThinkBook 14 G6 IRL 21KG00BQVN (...  22790000
# 3    Laptop MSI Gaming Katana 15 B13VFK 676VN (i7 1...  31990000
# 4    Laptop Acer Aspire A715-76-728X NH.QGESV.008 (...  20490000
# ..                                                 ...       ...
# 175  Laptop Asus Vivobook 14 X1404ZA-NK386W (i3 121...  12990000
# 176  Laptop Dell Inspiron 3520 25P2312 (i5 1235U/ 1...  17990000
# 177  Laptop Lenovo IdeaPad Slim 3 14IAH8 (i5 12450H...  15490000
# 178  Laptop HP 14s ep0112TU 8C5L1PA (i5 1335U/ 16GB...  18890000
# 179  Laptop HP Pavilion x360 14-ek1049TU 80R27PA (i...  23190000
#
#                        CPU Ram Memory  Size  \
# 0      Ultra 5 125H 1.2GHz  16    512  14.0
# 1       Core 5 120U 1.4GHz  16   1024  14.0
# 2     Core i7 1355U 1.7GHz  16    512  14.0
# 3    Core i7-13620H 2.4GHz  16   1024  15.6
# 4    Core i7 12650H 3.5GHz  16    512  15.6
# ..                     ...  ..    ...   ...
# 175   Core i3 1215U 1.2GHz   8    512  14.0
# 176   Core i5 1235U 1.3GHz  16    512  15.6
# 177  Core i5 12450H 3.3GHz  16    512  14.0
# 178   Core i5 1335U 1.3GHz  16    512  14.0
# 179   Core i5 1335U 1.3GHz  16    512  14.0
#
#                                    GPU  \
# 0                   Intel Arc Graphics
# 1                   Intel UHD Graphics
# 2               Intel Iris Xe Graphics
# 3    Nvidia GeForce RTX 4060 8GB GDDR6
# 4                   Intel UHD Graphics
# ..                                 ...
# 175                 Intel UHD Graphics
# 176                 Intel UHD Graphics
# 177                 Intel UHD Graphics
# 178             Intel Iris Xe Graphics
# 179             Intel Iris Xe Graphics
#
#                                                   Link
# 0    https://www.phucanh.vn/laptop-acer-swift-go-ai...
# 1    https://www.phucanh.vn/laptop-hp-14-ep1009tu-9...
# 2    https://www.phucanh.vn/laptop-lenovo-thinkbook...
# 3    https://www.phucanh.vn/laptop-msi-gaming-katan...
# 4    https://www.phucanh.vn/laptop-acer-aspire-gami...
# ..                                                 ...
# 175  https://www.phucanh.vn/laptop-asus-vivobook-14...
# 176  https://www.phucanh.vn/laptop-dell-inspiron-35...
# 177  https://www.phucanh.vn/laptop-lenovo-ideapad-s...
# 178  https://www.phucanh.vn/laptop-hp-14s-ep0112tu-...
# 179  https://www.phucanh.vn/laptop-hp-pavilion-x360...
#
# [180 rows x 8 columns]

# %%
df_laptopphucanh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    180 non-null    object
#  1   Price   172 non-null    object
#  2   CPU     180 non-null    object
#  3   Ram     180 non-null    object
#  4   Memory  180 non-null    object
#  5   Size    180 non-null    object
#  6   GPU     180 non-null    object
#  7   Link    180 non-null    object
# dtypes: object(8)
# memory usage: 11.4+ KB

# %% [markdown]
# ## Gộp dataframe

# %%
# Thêm dữ liệu từ df_laptopphucanh vào df 
df = pd.concat([df, df_laptopphucanh], ignore_index=True)
df = pd.concat([df, df_laptop88_Laptop_ankhang,df_LaptopAZ_Laptop_anphat], ignore_index=True)
df
# Out:
#                                                   Name      Price  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...   10500000
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...   10500000
# 2    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...   11500000
# 3    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...   10900000
# 4    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...   12900000
# ..                                                 ...        ...
# 961  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46990000
# 962  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000
# 963  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54990000
# 964  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000
# 965  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000
#
#                                                 CPU  Ram  Memory  Size  \
# 0                                     Core i7-8550U    8     256  13.3
# 1                                    Core i7- 7500U    8     256  13.3
# 2                                           Core i7   16     256  13.3
# 3                                     Core I5*8265U    8     256  13.3
# 4                                    Core i7- 8565U   16     256  13.3
# ..                                              ...  ...     ...   ...
# 961                                 Core i7-14650HX   16  1024.0  16.0
# 962  Ryzen AI 9 HX 370; AMD Ryzen™ AI up to 81 TOPs    8  1024.0  14.0
# 963                       Core i7-13650HX Processor   16   512.0  16.0
# 964                                   Core i7-1355U   16   512.0  14.0
# 965                                   Core i5-1335U  16    512.0  13.3
#
#                                                    GPU  \
# 0                                Intel HD Graphics 620
# 1                                Intel HD Graphics 620
# 2                               Intel UHD Graphics 620
# 3                               Intel UHD Graphics 620
# 4                               Intel UHD Graphics 620
# ..                                                 ...
# 961       NVIDIA® GeForce RTX 4060 8 GB (AI TOPS: 233)
# 962  NVIDIA® GeForce RTX™ 4060 8GB GDDR6 (AI TOPS: ...
# 963                  NVIDIA GeForce RTX 4070 8GB GDDR6
# 964                                Intel Intel Iris Xe
# 965                                 Intel UHD Graphics
#
#                                                   Link
# 0    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1    https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2    https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 4    https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..                                                 ...
# 961                                                NaN
# 962  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 963                                                NaN
# 964  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 965  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
# [966 rows x 8 columns]

# %%
# Chuyển các cột còn lại thành số nếu có thể
df = df.apply(pd.to_numeric, errors='ignore')

# %%
# Thêm cột CPU_type dựa trên cột Price
def classify_cpu(price):
    if price <= 17000000:
        return "Entry-level"
    elif 17000000 < price <= 25000000:
        return "Mid-range"
    elif 25000000 < price <= 45000000:
        return "High-class"
    else:
        return "Premium"
# Thêm cột GPU_type dựa trên cột Price
def classify_gpu(price):
    if price <= 15000000:
        return "Universal"
    elif 15000000 < price <= 25000000:
        return "Mid-range"
    elif 25000000 < price <= 40000000:
        return "High-class-graphics-gaming"
    else:
        return "High-class-workstation"

df["GPU_type"] = df["Price"].apply(classify_gpu)
df["CPU_type"] = df["Price"].apply(classify_cpu)
df=df.drop(columns=['CPU','GPU'])
df
# Out:
#                                                   Name       Price   Ram  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10500000.0   8.0
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10500000.0   8.0
# 2    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11500000.0  16.0
# 3    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10900000.0   8.0
# 4    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12900000.0  16.0
# ..                                                 ...         ...   ...
# 961  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46990000.0  16.0
# 962  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000.0   8.0
# 963  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54990000.0  16.0
# 964  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000.0  16.0
# 965  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000.0  16.0
#
#      Memory  Size                                               Link  \
# 0     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2     256.0  13.3  https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 4     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..      ...   ...                                                ...
# 961  1024.0  16.0                                                NaN
# 962  1024.0  14.0  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 963   512.0  16.0                                                NaN
# 964   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 965   512.0  13.3  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                    GPU_type     CPU_type
# 0                 Universal  Entry-level
# 1                 Universal  Entry-level
# 2                 Universal  Entry-level
# 3                 Universal  Entry-level
# 4                 Universal  Entry-level
# ..                      ...          ...
# 961  High-class-workstation      Premium
# 962  High-class-workstation   High-class
# 963  High-class-workstation      Premium
# 964               Mid-range    Mid-range
# 965               Mid-range    Mid-range
#
# [966 rows x 8 columns]

# %%
# df = df[df['CPU'].str.len().between(10, 26)]
# df

# %%
df.describe()
# Out:
#               Price         Ram       Memory         Size
# count  9.580000e+02  957.000000   955.000000   962.000000
# mean   2.485930e+07   18.993730   579.179058    26.544699
# std    1.222632e+07   38.649265   234.334573   195.262480
# min    3.900000e+06    4.000000     2.000000    10.500000
# 25%    1.699000e+07   16.000000   512.000000    14.000000
# 50%    2.199000e+07   16.000000   512.000000    15.600000
# 75%    2.899000e+07   16.000000   512.000000    15.600000
# max    8.500000e+07  816.000000  2048.000000  4060.000000

# %%
# Tính tần suất xuất hiện của các giá trị trong cột 'Ram' và 'Memory'
df['Ram'].value_counts()
# Out:
# 16.0     620
# 8.0      183
# 32.0     106
# 12.0      24
# 24.0      10
# 64.0       8
# 512.0      3
# 816.0      1
# 5.0        1
# 4.0        1
# Name: Ram, dtype: int64

# %%
df['Memory'].value_counts()
# Out:
# 512.0     680
# 1024.0    176
# 256.0      87
# 32.0        3
# 16.0        3
# 128.0       2
# 2.0         2
# 8.0         1
# 2048.0      1
# Name: Memory, dtype: int64

# %%
df['Size'].value_counts()
# Out:
# 15.6      384
# 14.0      269
# 16.0      179
# 13.3       38
# 14.5       19
# 17.0       13
# 13.4       12
# 17.3       10
# 15.0        9
# 18.0        5
# 13.5        4
# 13.0        3
# 14.2        2
# 12.5        2
# 13.6        2
# 16.1        2
# 512.0       2
# 10.5        1
# 15.3        1
# 4050.0      1
# 1920.0      1
# 16.3        1
# 4060.0      1
# 53.0        1
# Name: Size, dtype: int64

# %%
# Tính tần suất xuất hiện
ram_counts = df['Ram'].value_counts()
memory_counts = df['Memory'].value_counts()
size_counts = df['Size'].value_counts()
# Lọc các giá trị xuất hiện ít hơn 5 lần
valid_rams = ram_counts[ram_counts >= 5].index
valid_memories = memory_counts[memory_counts >= 5].index
valid_size = size_counts[size_counts >= 5].index
# Cập nhật DataFrame bằng cách chỉ giữ lại các giá trị hợp lệ
df = df[df['Ram'].isin(valid_rams) & df['Memory'].isin(valid_memories)& df['Size'].isin(valid_size)]

# %%
df['Memory'].value_counts()
# Out:
# 512.0     664
# 1024.0    171
# 256.0      81
# Name: Memory, dtype: int64

# %%
df['Ram'].value_counts()
# Out:
# 16.0    600
# 8.0     176
# 32.0     99
# 12.0     24
# 24.0     10
# 64.0      7
# Name: Ram, dtype: int64

# %%
df['Size'].value_counts()
# Out:
# 15.6    380
# 14.0    263
# 16.0    172
# 13.3     36
# 14.5     19
# 17.0     13
# 13.4     11
# 17.3     10
# 15.0      7
# 18.0      5
# Name: Size, dtype: int64

# %%
df
# Out:
#                                                   Name       Price   Ram  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10500000.0   8.0
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10500000.0   8.0
# 2    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11500000.0  16.0
# 3    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10900000.0   8.0
# 4    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12900000.0  16.0
# ..                                                 ...         ...   ...
# 961  Laptop Acer Predator Helios Neo PHN16-72-78DQ_...  46990000.0  16.0
# 962  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000.0   8.0
# 963  Laptop Asus ROG Strix G16 G614JI-N4125W (Intel...  54990000.0  16.0
# 964  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000.0  16.0
# 965  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000.0  16.0
#
#      Memory  Size                                               Link  \
# 0     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2     256.0  13.3  https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 4     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..      ...   ...                                                ...
# 961  1024.0  16.0                                                NaN
# 962  1024.0  14.0  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 963   512.0  16.0                                                NaN
# 964   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 965   512.0  13.3  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                    GPU_type     CPU_type
# 0                 Universal  Entry-level
# 1                 Universal  Entry-level
# 2                 Universal  Entry-level
# 3                 Universal  Entry-level
# 4                 Universal  Entry-level
# ..                      ...          ...
# 961  High-class-workstation      Premium
# 962  High-class-workstation   High-class
# 963  High-class-workstation      Premium
# 964               Mid-range    Mid-range
# 965               Mid-range    Mid-range
#
# [916 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 0 to 965
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      916 non-null    object
#  1   Price     908 non-null    float64
#  2   Ram       916 non-null    float64
#  3   Memory    916 non-null    float64
#  4   Size      916 non-null    float64
#  5   Link      877 non-null    object
#  6   GPU_type  916 non-null    object
#  7   CPU_type  916 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 64.4+ KB

# %%
df=df.dropna()

# %%
df
# Out:
#                                                   Name       Price   Ram  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10500000.0   8.0
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10500000.0   8.0
# 2    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11500000.0  16.0
# 3    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10900000.0   8.0
# 4    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12900000.0  16.0
# ..                                                 ...         ...   ...
# 959  Laptop HP EliteBook 640 G10 873G3PA (Intel Cor...  24490000.0  16.0
# 960  Laptop HP 15-fd0083TU 8D736PA (Intel Core i7-1...  22590000.0  16.0
# 962  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000.0   8.0
# 964  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000.0  16.0
# 965  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000.0  16.0
#
#      Memory  Size                                               Link  \
# 0     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2     256.0  13.3  https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 4     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..      ...   ...                                                ...
# 959   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
# 960   512.0  15.6  https://www.anphatpc.com.vn/laptop-hp-15-fd008...
# 962  1024.0  14.0  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 964   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 965   512.0  13.3  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                    GPU_type     CPU_type
# 0                 Universal  Entry-level
# 1                 Universal  Entry-level
# 2                 Universal  Entry-level
# 3                 Universal  Entry-level
# 4                 Universal  Entry-level
# ..                      ...          ...
# 959               Mid-range    Mid-range
# 960               Mid-range    Mid-range
# 962  High-class-workstation   High-class
# 964               Mid-range    Mid-range
# 965               Mid-range    Mid-range
#
# [869 rows x 8 columns]

# %%
df.to_excel("Laptops_dataset.xlsx", index=False)

# %%
df.describe()
# Out:
#               Price         Ram       Memory        Size
# count  8.690000e+02  869.000000   869.000000  869.000000
# mean   2.423770e+07   16.543153   581.818182   15.106559
# std    1.186857e+07    7.517693   221.934580    0.968842
# min    5.900000e+06    8.000000   256.000000   13.300000
# 25%    1.680000e+07   16.000000   512.000000   14.000000
# 50%    2.180000e+07   16.000000   512.000000   15.600000
# 75%    2.799000e+07   16.000000   512.000000   15.600000
# max    8.500000e+07   64.000000  1024.000000   18.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Biểu đồ Histogram cho RAM
plt.figure(figsize=(8, 5))
sns.histplot(df['Ram'], bins=5, kde=True, color='orange')
plt.title('Phân bố RAM Laptop')
plt.xlabel('RAM (GB)')
plt.ylabel('Tần số')
plt.show()

# Biểu đồ Histogram cho Size
plt.figure(figsize=(8, 5))
sns.histplot(df['Size'], bins=5, kde=True, color='green')
plt.title('Phân bố kích thước màn hình Laptop')
plt.xlabel('Kích thước (inch)')
plt.ylabel('Tần số')
plt.show()
# Biểu đồ Histogram cho Size
plt.figure(figsize=(8, 5))
sns.histplot(df['CPU_type'], bins=5, kde=True, color='green')
plt.title('Phân bố kích thước màn hình Laptop')
plt.xlabel('Kích thước (inch)')
plt.ylabel('Tần số')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Loại bỏ các giá trị null trong cột số
numeric_columns = ["Price", "Ram", "Memory", "Size"]
df_clean = df.dropna(subset=numeric_columns)

# 1. Vẽ Boxplot cho các cột số
plt.figure(figsize=(16, 8))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 2, i)  # Tạo 2x2 subplots
    sns.boxplot(data=df_clean, y=col)
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# # 2. Vẽ Scatter plot giữa cột 'Price' và các cột còn lại
# plt.figure(figsize=(16, 8))
# for i, col in enumerate(numeric_columns[1:], 1):  # Loại cột 'Price' khỏi vòng lặp
#     plt.subplot(2, 2, i)
#     sns.scatterplot(data=df_clean, x=col, y="Price", hue="GPU")
#     plt.title(f"Scatter Plot: {col} vs Price")
# plt.tight_layout()
# plt.show()

# %%
# # Hàm loại bỏ ngoại lai cho toàn bộ DataFrame
# def remove_outliers(df):
#     # Lọc các cột số
#     numeric_columns = df.select_dtypes(include=["number"]).columns
#     # Tạo một bản sao của DataFrame để giữ nguyên bản gốc
#     df_clean = df.copy()
    
#     # Áp dụng loại bỏ ngoại lai cho tất cả các cột số
#     for col in numeric_columns:
#         Q1 = df_clean[col].quantile(0.25)
#         Q3 = df_clean[col].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
    
#     return df_clean

# # Loại bỏ ngoại lai cho toàn bộ DataFrame
# df_clean = remove_outliers(df)

# # Vẽ lại Boxplot sau khi loại bỏ ngoại lai
# plt.figure(figsize=(16, 8))
# numeric_columns = df_clean.select_dtypes(include=["number"]).columns
# for i, col in enumerate(numeric_columns, 1):
#     plt.subplot(2, 2, i)
#     sns.boxplot(data=df_clean, y=col)
#     plt.title(f"Boxplot of {col} (Without Outliers)")
# plt.tight_layout()
# plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Giả sử bạn đã có DataFrame df
# Tạo một bản sao của DataFrame để đảm bảo tính nguyên bản của dữ liệu
df_encoded = df.copy()
df_encoded=df_encoded.drop(columns=["Name","Link"])
# Label encoding cho các cột kiểu object
label_encoders = {}
categorical_columns = ['CPU_type', 'GPU_type']

for col in categorical_columns:
    label_encoder = LabelEncoder()
    df_encoded[col] = label_encoder.fit_transform(df_encoded[col])
    label_encoders[col] = label_encoder  # Lưu label encoder cho việc sử dụng sau này (nếu cần)

# Chuẩn hóa các cột số (Price, Ram, Memory, Size)
scaler = StandardScaler()
numerical_columns = ['Price', 'Ram', 'Memory', 'Size']
df_encoded[numerical_columns] = scaler.fit_transform(df_encoded[numerical_columns])

# Hiển thị kết quả
df_encoded
# Out:
#         Price       Ram    Memory      Size  GPU_type  CPU_type
# 0   -1.158152 -1.137061 -1.468928 -1.865732         3         0
# 1   -1.158152 -1.137061 -1.468928 -1.865732         3         0
# 2   -1.073847 -0.072292 -1.468928 -1.865732         3         0
# 3   -1.124430 -1.137061 -1.468928 -1.865732         3         0
# 4   -0.955820 -0.072292 -1.468928 -1.865732         3         0
# ..        ...       ...       ...       ...       ...       ...
# 959  0.021270 -0.072292 -0.314770 -1.142804         2         2
# 960 -0.138908 -0.072292 -0.314770  0.509603         2         2
# 962  1.749516 -1.137061  1.993544 -1.142804         1         1
# 964 -0.189491 -0.072292 -0.314770 -1.142804         2         2
# 965  0.012840 -0.072292 -0.314770 -1.865732         2         2
#
# [869 rows x 6 columns]

# %%
# Tính ma trận tương quan
correlation_matrix = df_encoded.corr()

# Vẽ heatmap
plt.figure(figsize=(30, 15))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap of Feature Correlation")
plt.show()

# %% [markdown]
# # Model

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_absolute_error
import joblib
from sklearn.base import BaseEstimator, TransformerMixin

# %%
df=df.dropna()
df
# Out:
#                                                   Name       Price   Ram  \
# 0    Dell XPS 13 9360 | Core i7-8550U | Ram 8GB | S...  10500000.0   8.0
# 1    Dell XPS 13 9360 |Core i7- 7500U | Ram 8GB | S...  10500000.0   8.0
# 2    Laptop Cũ Dell XPS 13 9370 | Core i7 – 8550U| ...  11500000.0  16.0
# 3    Dell XPS 13 9380 Core I5*8265U/ RAM 8GB/ SSD 2...  10900000.0   8.0
# 4    Dell XPS 13 9380 Core i7- 8565U/ RAM 16GB/ SSD...  12900000.0  16.0
# ..                                                 ...         ...   ...
# 959  Laptop HP EliteBook 640 G10 873G3PA (Intel Cor...  24490000.0  16.0
# 960  Laptop HP 15-fd0083TU 8D736PA (Intel Core i7-1...  22590000.0  16.0
# 962  Laptop ASUS TUF Gaming A14 FA401WV-RG062WS (AM...  44990000.0   8.0
# 964  Laptop HP 14s-ep0110TU 8C5K9PA (Intel Core i7-...  21990000.0  16.0
# 965  Laptop HP Elitebook 630 G10 9J0B5PT (Intel Cor...  24390000.0  16.0
#
#      Memory  Size                                               Link  \
# 0     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 1     256.0  13.3  https://laptoptcc.com/dell-xps-13-9360-i5-7200...
# 2     256.0  13.3  https://laptoptcc.com/laptop-cu-dell-xps-13-93...
# 3     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# 4     256.0  13.3  https://laptoptcc.com/dell-xps-13-9380-i7-8565...
# ..      ...   ...                                                ...
# 959   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
# 960   512.0  15.6  https://www.anphatpc.com.vn/laptop-hp-15-fd008...
# 962  1024.0  14.0  https://www.anphatpc.com.vn/laptop-asus-tuf-ga...
# 964   512.0  14.0  https://www.anphatpc.com.vn/laptop-hp-14s-ep01...
# 965   512.0  13.3  https://www.anphatpc.com.vn/laptop-hp-eliteboo...
#
#                    GPU_type     CPU_type
# 0                 Universal  Entry-level
# 1                 Universal  Entry-level
# 2                 Universal  Entry-level
# 3                 Universal  Entry-level
# 4                 Universal  Entry-level
# ..                      ...          ...
# 959               Mid-range    Mid-range
# 960               Mid-range    Mid-range
# 962  High-class-workstation   High-class
# 964               Mid-range    Mid-range
# 965               Mid-range    Mid-range
#
# [869 rows x 8 columns]

# %% [markdown]
# ### Seperating the Columns:

# %%
cpu_values = sorted(df['CPU_type'].unique().tolist())
cpu_values
# Out:
# ['Entry-level', 'High-class', 'Mid-range', 'Premium']

# %% [markdown]
# Selecting the Numerical and Categorical Columns.

# %%
# Define the columns
categorical_columns = df.drop(columns=["Name","Link"]).select_dtypes(include=['object']).columns.tolist()
numerical_columns = df.drop(columns=["Name","Link"]).select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_columns.remove('Price')  # Exclude the target column from numerical columns

# %% [markdown]
# ### Scaling and Encoding:

# %%
# Tạo transformer tùy chỉnh sử dụng LabelEncoder
class LabelEncoderTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoders = {}

    def fit(self, X, y=None):
        for col in X.columns:
            le = LabelEncoder()
            le.fit(X[col])
            self.encoders[col] = le
        return self

    def transform(self, X):
        X_transformed = X.copy()
        for col in X.columns:
            X_transformed[col] = self.encoders[col].transform(X[col])
        return X_transformed

    def inverse_transform(self, X):
        X_inverse = X.copy()
        for col in X.columns:
            X_inverse[col] = self.encoders[col].inverse_transform(X[col])
        return X_inverse

# %%
# Create transformers for numerical and categorical features
numerical_transformer = StandardScaler()
categorical_transformer = LabelEncoderTransformer()

# Combine transformers into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_columns),
        ('cat', categorical_transformer, categorical_columns)
    ])

# %% [markdown]
# ## Splitting the Dataset:

# %%
# Create and fit the preprocessing pipeline
X = df.drop(columns=[ 'Price']) 
y = df['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,shuffle=True)

preprocessor.fit(X_train)

# Save the preprocessor
joblib.dump(preprocessor, 'preprocessor.pkl')
# Out:
# ['preprocessor.pkl']

# %% [markdown]
# ## Defining the Models and Training:

# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# Định nghĩa các model ban đầu
models = {
    "Decision Tree": DecisionTreeRegressor(max_depth=10, random_state=42),
    "Random Forest": RandomForestRegressor(n_estimators=100, max_depth=100, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=100, random_state=42),
    # "LightGBM": LGBMRegressor(n_estimators=100, learning_rate=0.1, force_row_wise=True, random_state=42)
}

best_model = None
best_score = float('-inf')  # Giá trị R² khởi tạo
best_model_name = ""


# Biến lưu kết quả
results = {"Model": [], "R²": [], "MAE": [], "RMSE": []}

# Vòng lặp huấn luyện và đánh giá
while best_score <= 0.95:  # Tiếp tục cho đến khi R² > 0.95
    # Dữ liệu (giả định `df` đã được chuẩn bị)
    X = df.drop(columns=['Price'])  # Các đặc trưng
    y = df['Price']  # Biến mục tiêu
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

   
    for name, model in models.items():
        # Huấn luyện mô hình
        model.fit(preprocessor.transform(X_train), y_train)
        
        # Dự đoán
        y_pred = model.predict(preprocessor.transform(X_test))
        
        # Tính toán các độ đo
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        
        # Lưu kết quả
        results["Model"].append(name)
        results["R²"].append(r2)
        results["MAE"].append(mae)
        results["RMSE"].append(rmse)
        
        # In kết quả
        print(f"{name} - R² score: {r2:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
        
        # Lưu mô hình
        joblib.dump(model, f"{name.replace(' ', '_')}.pkl")
        
        # Lưu lại mô hình tốt nhất
        if r2 > best_score:
            best_score = r2
            best_model = model
            best_model_name = name
    
    # Kiểm tra điều kiện dừng
    if best_score > 0.95:
        break
# Out:
# Decision Tree - R² score: 0.9233, MAE: 220668.1394, RMSE: 308892.7929
# Random Forest - R² score: 0.9189, MAE: 221594.0113, RMSE: 317599.6110
# XGBoost - R² score: 0.9224, MAE: 223029.1989, RMSE: 310718.3758
# XGBoost - R² score: 0.8722, MAE: 256617.4954, RMSE: 393325.5940
# Decision Tree - R² score: 0.9044, MAE: 258416.6640, RMSE: 392000.8256
# Random Forest - R² score: 0.9121, MAE: 256930.3002, RMSE: 375794.6665
# XGBoost - R² score: 0.9022, MAE: 263799.9989, RMSE: 396341.1906
# Decision Tree - R² score: 0.9360, MAE: 216898.9844, RMSE: 277842.7164
# Random Forest - R² score: 0.9399, MAE: 212256.1307, RMSE: 269277.7994
# XGBoost - R² score: 0.9332, MAE: 219685.4023, RMSE: 283764.3559
# Decision Tree - R² score: 0.9127, MAE: 236962.8605, RMSE: 337111.7672
# Random Forest - R² score: 0.9127, MAE: 240116.4165, RMSE: 337077.7202
# XGBoost - R² score: 0.9013, MAE: 246355.6190, RMSE: 358532.1894
# Decision Tree - R² score: 0.8782, MAE: 269014.8212, RMSE: 461000.6478
# Random Forest - R² score: 0.8993, MAE: 256600.8730, RMSE: 419180.2285
# XGBoost - R² score: 0.8958, MAE: 262033.5213, RMSE: 426339.0048
# Decision Tree - R² score: 0.8737, MAE: 262098.1342, RMSE: 415816.0599
# Random Forest - R² score: 0.8822, MAE: 256047.0760, RMSE: 401628.1569
# XGBoost - R² score: 0.8837, MAE: 258083.7310, RMSE: 398990.9912
# Decision Tree - R² score: 0.9519, MAE: 197422.4033, RMSE: 266981.2867
# Random Forest - R² score: 0.9441, MAE: 207253.7995, RMSE: 287848.8012
# XGBoost - R² score: 0.9521, MAE: 196812.7678, RMSE: 266603.0289

# %%
# ---------------------------------
# Đánh giá các mô hình đã lưu
# ---------------------------------
loaded_results = {"Model": [], "R²": [], "MAE": [], "RMSE": []}

for name in models.keys():
    # Load mô hình
    model = joblib.load(f"{name.replace(' ', '_')}.pkl")
    
    # Dự đoán
    y_pred = model.predict(preprocessor.transform(X_test))
    
    # Tính toán các độ đo
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)/10
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))/10
    
    # Lưu kết quả
    loaded_results["Model"].append(name)
    loaded_results["R²"].append(r2)
    loaded_results["MAE"].append(mae)
    loaded_results["RMSE"].append(rmse)

# ---------------------------------
# Vẽ biểu đồ
# ---------------------------------

# Biểu đồ so sánh R²
plt.figure(figsize=(10, 6))
bars_r2 = plt.bar(loaded_results["Model"], loaded_results["R²"], color='skyblue')
plt.title("Comparison of R² Scores")
plt.ylabel("R² Score")
plt.xlabel("Models")
plt.xticks(rotation=45)

# Hiển thị giá trị R² trên các thanh
for bar in bars_r2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.savefig("comparison_r2.png")
plt.show()

# Biểu đồ so sánh MAE và RMSE
x = np.arange(len(loaded_results["Model"]))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, loaded_results["MAE"], width, label='MAE', color='orange')
rects2 = ax.bar(x + width/2, loaded_results["RMSE"], width, label='RMSE', color='green')

ax.set_title("Comparison of MAE and RMSE")
ax.set_xticks(x)
ax.set_xticklabels(loaded_results["Model"], rotation=45)
ax.set_ylabel("Error")
ax.set_xlabel("Models")
ax.legend()

# Hiển thị giá trị MAE và RMSE trên các thanh
for rect in rects1:
    yval = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

for rect in rects2:
    yval = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

fig.tight_layout()
plt.savefig("comparison_mae_rmse.png")
plt.show()

# %%
# Lưu lại mô hình tốt nhất
joblib.dump(best_model, 'best_model.pkl')

print(f"Best model: {best_model_name} with R² score: {best_score:.4f}")
# Out:
# Best model: XGBoost with R² score: 0.9521

# %% [markdown]
# ## Hyperparameter Tuning:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import joblib
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# Định nghĩa models và hyperparameter grid
models = {
    "Decision Tree": (DecisionTreeRegressor(random_state=42), {
        'max_depth': [5, 10, 15, 20, None],
        'min_samples_split': [2, 5, 10]
    }),
    "Random Forest": (RandomForestRegressor(random_state=42), {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30]
    }),
    "XGBoost": (XGBRegressor(random_state=42), {
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 4, 5, 6],
        'learning_rate': [0.01, 0.1, 0.2]
    }),
}

# Khởi tạo giá trị ban đầu
best_model = None
best_score = float('-inf')  # Giá trị R² khởi tạo
best_model_name = ""

# Khởi tạo danh sách lưu kết quả
results = {"Model": [], "R2": [], "RMSE": [], "MAE": []}

# Giả định dữ liệu đã tiền xử lý
X = df.drop(columns=['Price'])
y = df['Price']


while best_score <= 0.94:
    for name, (model, param_grid) in models.items():
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , shuffle=True)
        print(f"Tuning hyperparameters for {name}...")

        # Tuning hyperparameters với RandomizedSearchCV
        search = RandomizedSearchCV(
            model, param_grid, n_iter=10, cv=5, scoring='r2', random_state=42, n_jobs=-1
        )
        search.fit(preprocessor.transform(X_train), y_train)

        # Mô hình với bộ tham số tốt nhất
        best_model_for_name = search.best_estimator_

        # Dự đoán
        y_pred = best_model_for_name.predict(preprocessor.transform(X_test))

        # Tính toán các độ đo
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))

        # Lưu kết quả vào danh sách
        results["Model"].append(name)
        results["R2"].append(r2)
        results["RMSE"].append(rmse)
        results["MAE"].append(mae)

        # In kết quả
        print(f"{name} - R² score: {r2:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}")

        # Lưu lại mô hình tốt nhất dựa trên R²
        if r2 > best_score:
            best_score = r2
            best_model = best_model_for_name
            best_model_name = name
        # Lưu model với tên chứa tên model và siêu tham số
        hyperparams = search.best_params_
        hyperparams_str = "_".join([f"{key}={value}" for key, value in hyperparams.items()])
        model_filename = f"{name}_hyperparams.pkl"
        joblib.dump(best_model_for_name, model_filename)
        print(f"Model saved: {model_filename}")
    # Kiểm tra nếu đạt điều kiện
    if best_score > 0.94:
        print(f"Stopping training as R² > 0.94 achieved with {best_model_name}")
        break
    else:
        print("R² chưa đạt > 0.94, tiếp tục huấn luyện lại...")
# Out:
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9140, RMSE: 371956.3397, MAE: 229871.0155
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9224, RMSE: 356194.3151, MAE: 238472.0884
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9297, RMSE: 363059.8400, MAE: 254848.2402
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9045, RMSE: 388015.8088, MAE: 256232.4318
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9171, RMSE: 308772.7231, MAE: 225953.0204
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.8916, RMSE: 331382.8533, MAE: 242647.1218
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8812, RMSE: 452315.1820, MAE: 259297.8380
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9222, RMSE: 346923.2738, MAE: 227910.3239
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9182, RMSE: 365683.0049, MAE: 247493.8609
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8263, RMSE: 557911.3594, MAE: 313509.3064
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9118, RMSE: 389139.2372, MAE: 255004.9147
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9025, RMSE: 366512.0202, MAE: 246095.2040
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9151, RMSE: 356240.0399, MAE: 250291.5693
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.8656, RMSE: 410901.5548, MAE: 259281.1957
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9006, RMSE: 400495.1531, MAE: 265585.3736
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9035, RMSE: 386533.2364, MAE: 236910.0540
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.8848, RMSE: 324906.5732, MAE: 232162.6461
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9361, RMSE: 304177.4417, MAE: 224882.9374
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9131, RMSE: 382249.4139, MAE: 239763.1086
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9154, RMSE: 324808.4750, MAE: 223408.3829
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.8657, RMSE: 502431.3543, MAE: 299799.0414
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8713, RMSE: 449051.3645, MAE: 257366.1836
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9356, RMSE: 295509.2368, MAE: 200370.5357
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9104, RMSE: 343243.0011, MAE: 244507.0851
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9047, RMSE: 340385.2845, MAE: 247127.4483
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.8887, RMSE: 346077.3730, MAE: 228250.8602
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.8868, RMSE: 395024.6040, MAE: 245381.2270
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8939, RMSE: 405212.6540, MAE: 253955.8958
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9201, RMSE: 332569.0101, MAE: 227273.5769
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9052, RMSE: 357165.9849, MAE: 224167.8897
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9151, RMSE: 377249.9136, MAE: 244919.6706
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9278, RMSE: 342252.0592, MAE: 241857.0296
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9024, RMSE: 378416.0627, MAE: 258402.1448
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8796, RMSE: 421770.3183, MAE: 256634.6566
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.8988, RMSE: 380919.9518, MAE: 267745.2948
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9251, RMSE: 334101.2981, MAE: 251089.7092
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8852, RMSE: 417302.1526, MAE: 261351.7888
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9060, RMSE: 347246.0597, MAE: 242547.8178
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9031, RMSE: 378270.1734, MAE: 249266.2592
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8847, RMSE: 397777.8132, MAE: 255596.0670
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9223, RMSE: 343752.4284, MAE: 233217.3945
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.8897, RMSE: 400033.4685, MAE: 266241.8397
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.8832, RMSE: 363401.8948, MAE: 243941.2171
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.8695, RMSE: 521085.0450, MAE: 297989.8397
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.8711, RMSE: 441545.5143, MAE: 240730.8264
# Model saved: XGBoost_hyperparams.pkl
# R² chưa đạt > 0.94, tiếp tục huấn luyện lại...
# Tuning hyperparameters for Decision Tree...
# Decision Tree - R² score: 0.9024, RMSE: 372945.5477, MAE: 234166.1746
# Model saved: Decision Tree_hyperparams.pkl
# Tuning hyperparameters for Random Forest...
# Random Forest - R² score: 0.9493, RMSE: 271039.5436, MAE: 199030.3893
# Model saved: Random Forest_hyperparams.pkl
# Tuning hyperparameters for XGBoost...
# XGBoost - R² score: 0.9242, RMSE: 302268.8684, MAE: 219545.3224
# Model saved: XGBoost_hyperparams.pkl
# Stopping training as R² > 0.94 achieved with Random Forest

# %%
# ---------------------------------
# Đánh giá các mô hình đã lưu
# ---------------------------------
loaded_results = {"Model": [], "R²": [], "MAE": [], "RMSE": []}

for name in models.keys():
    # Load mô hình
    model = joblib.load(f"{name}_hyperparams.pkl")
    
    # Dự đoán
    y_pred = model.predict(preprocessor.transform(X_test))
    
    # Tính toán các độ đo
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)/10
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))/10
    
    # Lưu kết quả
    loaded_results["Model"].append(name)
    loaded_results["R²"].append(r2)
    loaded_results["MAE"].append(mae)
    loaded_results["RMSE"].append(rmse)

# ---------------------------------
# Vẽ biểu đồ
# ---------------------------------

# Biểu đồ so sánh R²
plt.figure(figsize=(10, 6))
bars_r2 = plt.bar(loaded_results["Model"], loaded_results["R²"], color='skyblue')
plt.title("Comparison of R² Scores")
plt.ylabel("R² Score")
plt.xlabel("Models")
plt.xticks(rotation=45)

# Hiển thị giá trị R² trên các thanh
for bar in bars_r2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.savefig("comparison_r2.png")
plt.show()

# Biểu đồ so sánh MAE và RMSE
x = np.arange(len(loaded_results["Model"]))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, loaded_results["MAE"], width, label='MAE', color='orange')
rects2 = ax.bar(x + width/2, loaded_results["RMSE"], width, label='RMSE', color='green')

ax.set_title("Comparison of MAE and RMSE")
ax.set_xticks(x)
ax.set_xticklabels(loaded_results["Model"], rotation=45)
ax.set_ylabel("Error")
ax.set_xlabel("Models")
ax.legend()

# Hiển thị giá trị MAE và RMSE trên các thanh
for rect in rects1:
    yval = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

for rect in rects2:
    yval = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

fig.tight_layout()
plt.savefig("comparison_mae_rmse.png")
plt.show()

# %%
# Load lại mô hình từ file cố định
loaded_best_model = joblib.load("hypertuned_best_model.pkl")

# %%
# # Lưu lại mô hình tốt nhất
# joblib.dump(best_model, 'hypertuned_best_model.pkl')

# print(f"Best model: {best_model_name} with R² score: {best_score:.4f}")

# %%
import joblib
import numpy as np
import pandas as pd

# Load the preprocessor and model
preprocessor = joblib.load('preprocessor.pkl')
model = joblib.load('best_model.pkl')  # Hoặc 'best_model.pkl' nếu không dùng hyperparameter tuning

# Định nghĩa một hàm để thực hiện dự đoán
def predict(features):
    """
    Thực hiện dự đoán giá laptop từ đặc trưng đầu vào.
    
    Parameters:
        features (dict): Từ điển chứa các đặc trưng cần dự đoán.
        
    Returns:
        float: Dự đoán giá.
    """
    # Chuyển dữ liệu đầu vào thành DataFrame để xử lý
    input_data = pd.DataFrame([features])  # Biến đổi thành một hàng duy nhất
    
    # Áp dụng preprocessing
    processed_data = preprocessor.transform(input_data)
    
    # Dự đoán giá
    prediction = model.predict(processed_data)
    
    return prediction[0]

# Ví dụ về đặc trưng đầu vào
input_features = {
      # Cột dạng chuỗi
    'Ram': 16,             # Cột số
    'Memory': 256,        # Cột số
    'CPU_type': 'High-class',     # Cột dạng chuỗi
    'GPU_type': 'Universal',   # Cột dạng chuỗi
    'Size': 13.3  ,   # Cột số
    # Thêm các đặc trưng khác nếu cần
}

# Thực hiện dự đoán
predicted_price = predict(input_features)
print(f"Dự đoán giá laptop: {predicted_price:.2f} VNĐ")
# Out:
# Dự đoán giá laptop: 19205952.00 VNĐ

# %% [markdown]
# <h1><b><p style="background-color:#09375b;font-family:camtasia;font-size:110%;color:white;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">THE END</p></b></h1>
